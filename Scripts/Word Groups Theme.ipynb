# %% [markdown]
# # THEMES FOR WORD GROUPS USING OpenAI
#
# **Authors**
# - Alejandro Urrego Lopéz
# - Cesar Augusto Prieto Sarmiento
#
# This python notebook contains the development of the code with which using the AI to generate the main themes or topics for each word group generated by the best clustering algorithm.

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd   # For data manipulations
import numpy as np    # For maths
import igraph as ig   # For networks 
import openai        # AI implementations
from dotenv import load_dotenv

import os
load_dotenv()
# openai.api_key =

# %%
data_folder_path = os.path.dirname(os.getcwd()) + os.sep + 'Outputs' + os.sep

# %%
# Definir la ruta del directorio de trabajo
directorio_trabajo = r'C:/Users/Pc/Desktop/-Proyecto-JEP-/Outputs/Skipgramas - Victimarios/General'
# Norte de santander
# Costa Caribe
# Casanare
# Meta
# Huila
# Antioquia
# Cambiar el directorio de trabajo
os.chdir(directorio_trabajo)

# %% [markdown]
# ## Development and research of topics

# %%
clusters = pd.read_csv('clusters_jep.txt')
clusters=clusters.sort_values(by='eigen', ascending=False)
clusters
# Out:
#              word  cluster         eigen
# 1        batallón        8  1.000000e+00
# 7      comandante       10  9.065017e-01
# 86             sé        7  7.928153e-01
# 10    información       10  7.559289e-01
# 17    operaciones       10  7.515524e-01
# ..            ...      ...           ...
# 918      forjando        4  8.531391e-09
# 612      céspedes        1  6.828890e-09
# 82     anticipada       12  5.553181e-09
# 662   transitoria       12  1.187256e-10
# 265  beneficiario       12  2.537155e-12
#
# [948 rows x 3 columns]

# %%
diccionario = {}
for i in set(clusters['cluster']):
    diccionario['cluster '+str(i)] = clusters.query('cluster==@i')['word'].tolist()

# %%
diccionario
# Out:
# {'cluster 1': ['tarea',
#   'material',
#   'auxiliar',
#   'omega',
#   'negro',
#   'intendencia',
#   'martínez',
#   'fabián',
#   'gerardo',
#   'céspedes'],
#  'cluster 2': ['relación',
#   'responsabilidad',
#   'civil',
#   'contacto',
#   'grado',
#   'integrantes',
#   'participó',
#   'nacional',
#   'población',
#   'bles',
#   'aducir',
#   'participaron',
#   'indirecta',
#   'causa',
#   'conductas',
#   'circunstancias',
#   'aceptación',
#   'libre',
#   'ausencia',
#   'protección',
#   'pública',
#   'existieron',
#   'miembros',
#   'colombia',
#   'indirectamente',
#   'determina',
#   'amnistia',
#   'detallado',
#   'estipulado',
#   'exhaustivo',
#   'adelantarse',
#   'asimismo',
#   'pondrá',
#   'reconozca'],
#  'cluster 3': ['dinero',
#   'cuarto',
#   'soto',
#   'autoría',
#   'reservados',
#   'consanguineidad',
#   'consanguinidad',
#   'gustavo',
#   'afinidad',
#   'partida',
#   'montaña'],
#  'cluster 4': ['número',
#   'superior',
#   'profesional',
#   'gobierno',
#   'despacho',
#   'virtud',
#   'abogado',
#   'infórmenos',
#   'movilidad',
#   'cédula',
#   'tarjeta',
#   'órgano',
#   'ciudad',
#   'identificado',
#   'convocado',
#   'bogotá',
#   'ciudadanía',
#   'consejo',
#   'portador',
#   'aprobó',
#   'rameli',
#   'fundación',
#   'corporación',
#   'quejada',
#   'identificarse',
#   'alejandro',
#   'privado',
#   'identifico',
#   'identificada',
#   'judicatura',
#   'vertical',
#   'futuros',
#   'afirmativo',
#   'arteaga',
#   'adscrito',
#   'forjando'],
#  'cluster 5': ['día',
#   'caso',
#   'días',
#   'pregunta',
#   'víctimas',
#   'quiero',
#   'perdón',
#   'versión',
#   'preguntas',
#   'rodríguez',
#   'mañana',
#   'diligencia',
#   'noche',
#   'respuesta',
#   'hora',
#   'audiencia',
#   'compareciente',
#   'público',
#   'llegamos',
#   'marco',
#   'presente',
#   'representante',
#   'propósito',
#   'presentación',
#   'representación',
#   'libertad',
#   'registro',
#   'participación',
#   'receso',
#   'tarde',
#   'voluntaria',
#   'horas',
#   'saludo',
#   'procuraduría',
#   'presentes',
#   'magistrados',
#   'señores',
#   'continuamos',
#   'instalar',
#   'marzo',
#   'tardes',
#   'permito',
#   'definidos',
#   'representar',
#   'comparece',
#   'jep',
#   'rigurosa',
#   'equipo',
#   'verificado',
#   'asistentes',
#   'garcía',
#   'procuradora',
#   'pido',
#   'magistratura',
#   'camilo',
#   'semana',
#   'proceda',
#   'tr',
#   'amable',
#   'presenta',
#   'proteger',
#   'representantes',
#   'tribunal',
#   'sociedad',
#   'darle',
#   'armado',
#   'encuentran',
#   'continuar',
#   'carlos',
#   'comparecientes',
#   'ofrecer',
#   'vigente',
#   'defensa',
#   'apoderados',
#   'acreditadas',
#   'familiares',
#   'abogados',
#   'calidad',
#   'masacre',
#   'colegas',
#   'auto',
#   'rendir',
#   'continuación',
#   'suspende',
#   'reanudamos',
#   'renovamos',
#   'remitir',
#   'perfecto',
#   'hacerle',
#   'generales',
#   'temas',
#   'edgar',
#   'fidel',
#   'febrero',
#   'presidir',
#   'intervinientes',
#   'profundizar',
#   'agosto',
#   'damos',
#   'mayo',
#   'septiembre',
#   'virtual',
#   'confesión',
#   'media',
#   'escuchar',
#   'versiones',
#   'distinguidos',
#   'medalla',
#   'restaurativas',
#   'nación',
#   'terminada',
#   'guerrero',
#   'turno',
#   'andrés',
#   'énfasis',
#   'actores',
#   'dr',
#   'autónomo',
#   'sujetos',
#   'vargas'],
#  'cluster 6': ['especial',
#   'militar',
#   'proceso',
#   'especiales',
#   'curso',
#   'investigación',
#   'desarrollo',
#   'salí',
#   'justicia',
#   'penal',
#   'paz',
#   'procedimiento',
#   'artículo',
#   'toma',
#   'centro',
#   'investigaciones',
#   'cambio',
#   'derechos',
#   'objetivo',
#   'cumplimiento',
#   'incumpla',
#   'aporte',
#   'buscar',
#   'ordinaria',
#   'corte',
#   'comprometida',
#   'sugerir',
#   'delitos',
#   'contribuir',
#   'plena',
#   'decisiones',
#   'escuela',
#   'declaración',
#   'evaluadas',
#   'reparación',
#   'juzgado',
#   'juez',
#   'repetición',
#   'acto',
#   'perderá',
#   'razones',
#   'formación',
#   'prestar',
#   'prestando',
#   'prestó',
#   'ingresé',
#   'satisfacer',
#   'entender',
#   'requerimientos',
#   'medidas',
#   'atender',
#   'satisfacción',
#   'consagrado',
#   'código',
#   'llamado',
#   'acopio',
#   'copia',
#   'humanos',
#   'suficientes',
#   'pérdida',
#   'absoluta',
#   'renuncias',
#   'agrupación',
#   'esclarecimiento',
#   'disciplinaria',
#   'derecho',
#   'legislativo',
#   'sistema',
#   'residencia',
#   'constitucional',
#   'permitan',
#   'gravedad',
#   'restaurativa',
#   'dispuestas',
#   'integral',
#   'duradera',
#   'tratamiento',
#   'comisión',
#   'permanente',
#   'inciso',
#   'especializado',
#   'declaraciones',
#   'compromisos',
#   'escenarios',
#   'intereclesial',
#   'derivadas',
#   'informar',
#   'breve',
#   'garantizar',
#   'colombiana',
#   'determinante',
#   'establecidos',
#   'final',
#   'quinto',
#   'grabada',
#   'parágrafo',
#   'conforme',
#   'estatutaria',
#   'condiciones',
#   'beneficios',
#   'garantías',
#   'cometer',
#   'secretario',
#   'observatorio',
#   'sujeta',
#   'condicionalidades',
#   'correspondan',
#   'aceptar',
#   'aportar',
#   'procesos',
#   'adicionalmente',
#   'sentencia',
#   'abstenerse',
#   'inmaterial',
#   'ejecución',
#   'obligación',
#   'detallada',
#   'relatar',
#   'cadetes',
#   'guerra',
#   'establecido',
#   'responsabilidades',
#   'inmediata',
#   'deber',
#   'tercero',
#   'circuito',
#   'entenderse',
#   'comprometió',
#   'transitorio',
#   'efecto',
#   'órganos',
#   'reparadoras',
#   'internacional',
#   'capacitación',
#   'materia',
#   'fiscal',
#   'cursos',
#   'territorio',
#   'surcolombiano',
#   'respeto',
#   'violaciones',
#   'exhaustiva',
#   'incurrir',
#   'tratamientos',
#   'consagrados',
#   'contribución',
#   'humanitario',
#   'dispuesto',
#   'conformidad',
#   'cualquiera',
#   'asesoría',
#   'impuestas',
#   'fundamental',
#   'materialización',
#   'cometidas',
#   'causales',
#   'palabras',
#   'necesarias',
#   'extrajudiciales',
#   'atribuir',
#   'condicionalidad',
#   'far',
#   'elementos',
#   'implica',
#   'sanciones',
#   'verificación',
#   'términos',
#   'significa',
#   'dolosa',
#   'octavo',
#   'disponga',
#   'infracciones',
#   'completa',
#   'falsa',
#   'incumplimiento',
#   'orientado'],
#  'cluster 7': ['sé',
#   'personas',
#   'pronto',
#   'orden',
#   'persona',
#   'recuerdo',
#   'acuerdo',
#   'soldados',
#   'pelotón',
#   'operación',
#   'iba',
#   'compañía',
#   'coronel',
#   'unidad',
#   'conocimiento',
#   'mí',
#   'digo',
#   'soldado',
#   'recuerda',
#   'teniente',
#   'grupo',
#   'claro',
#   'sargento',
#   'capitán',
#   'cuál',
#   'situación',
#   'ustedes',
#   'tenían',
#   'sección',
#   'dónde',
#   'área',
#   'oficial',
#   'mando',
#   'pasó',
#   'baja',
#   'personal',
#   'estuve',
#   'iban',
#   'época',
#   'sector',
#   'cabo',
#   'forma',
#   'sabía',
#   'punto',
#   'ah',
#   'sitio',
#   'seguridad',
#   'alguien',
#   'gente',
#   'mal',
#   'llega',
#   'llegué',
#   'allí',
#   'tuve',
#   'guía',
#   'víctima',
#   'podía',
#   'mire',
#   'hubiera',
#   'hablar',
#   'quiénes',
#   'exactamente',
#   'apellido',
#   'armas',
#   'nombres',
#   'moto',
#   'arma',
#   'casa',
#   'cuánto',
#   'escuadra',
#   'vi',
#   'llegaron',
#   'canadá',
#   'azteca',
#   'profesionales',
#   'disparó',
#   'regulares',
#   'vehículo',
#   'campesinos',
#   'disparos',
#   'suboficial',
#   'subteniente',
#   'brasil',
#   'carro',
#   'muchacho',
#   'berlín',
#   'catapulta',
#   'íbamos',
#   'hayan',
#   'conmigo',
#   'conozco',
#   'tendría',
#   'desconozco',
#   'ahorita',
#   'seguro',
#   'problema',
#   'sacaron',
#   'llevaron',
#   'desaparecidas',
#   'antecedentes',
#   'armamento',
#   'fueran',
#   'muertas',
#   'civiles',
#   'mirar',
#   'miedo',
#   'situaciones',
#   'pienso',
#   'tocaba',
#   'movimiento',
#   'fragmentaria',
#   'desaparición',
#   'captura',
#   'muerta',
#   'alias',
#   'acuerda',
#   'represente',
#   'cuadros',
#   'dinamarca',
#   'fusil',
#   'camioneta',
#   'tercer',
#   'bravo',
#   'peña',
#   'guarnizo',
#   'llamó',
#   'menor',
#   'acusación',
#   'gonzález',
#   'almario',
#   'bonilla',
#   'ilegal',
#   'argos',
#   'autoidentifica',
#   'palomino',
#   'jiménez',
#   'romero',
#   'padre',
#   'casado',
#   'estudios',
#   'actual',
#   'región',
#   'podían',
#   'aria',
#   'pueblo',
#   'hubieran',
#   'cortas',
#   'revólver',
#   'vio'],
#  'cluster 8': ['batallón',
#   'vida',
#   'guerrilla',
#   'correcto',
#   'encontraba',
#   'imagino',
#   'sale',
#   'normal',
#   'venía',
#   'llamaba',
#   'contraguerrilla',
#   'informante',
#   'casanare',
#   'trasladado',
#   'existía',
#   'llevaba',
#   'oficiales',
#   'lópez',
#   'infantería',
#   'plana',
#   'guzmán',
#   'escuchó',
#   'periodo',
#   'hablaba',
#   'medio',
#   'panza',
#   'normalmente',
#   'razón',
#   'reporte',
#   'decisión',
#   'informa',
#   'pasaba',
#   'maneja',
#   'directo',
#   'prácticamente',
#   'salía',
#   'plata',
#   'queda',
#   'entrenamiento',
#   'novena',
#   'agregado',
#   'cuarta',
#   'municipio',
#   'servicios',
#   'felicitaciones',
#   'particular',
#   'hombres',
#   'pinto',
#   'pico',
#   'salamanca',
#   'competencia',
#   'servicio',
#   'santa',
#   'cuándo',
#   'zona',
#   'departamento',
#   'vereda',
#   'conocía',
#   'listo',
#   'noviembre',
#   'octubre',
#   'junio',
#   'organización',
#   'municipios',
#   'cuántas',
#   'inicialmente',
#   'llegan',
#   'habla',
#   'quedaba',
#   'teníamos',
#   'llego',
#   'nuevamente',
#   'asignado',
#   'rillas',
#   'justo',
#   'puerto',
#   'tenerife',
#   'siquiera',
#   'conoció',
#   'salgo',
#   'estando',
#   'radial',
#   'supo',
#   'salimos',
#   'vehículos',
#   'duré',
#   'anza',
#   'cree',
#   'llegaban',
#   'estábamos',
#   'llamar',
#   'entendí',
#   'pitalito',
#   'llegado',
#   'recién',
#   'rías',
#   'informaba',
#   'digámoslo',
#   'recuerde',
#   'suboficiales',
#   'extracto',
#   'felicitación',
#   'david',
#   'autodefensas',
#   'kit',
#   'vera',
#   'azul',
#   'siguientes',
#   'marcos',
#   'bandas',
#   'ituango',
#   'itango',
#   'tuango',
#   'cauca',
#   'rita',
#   'corregimiento',
#   'ocurre',
#   'indígena',
#   'delincuente',
#   'cuántos',
#   'antioquia',
#   'óscar'],
#  'cluster 9': ['resultados',
#   'combate',
#   'bajas',
#   'resultado',
#   'permiso',
#   'muerte',
#   'operacional',
#   'casos',
#   'operacionales',
#   'hablando',
#   'muertes',
#   'salir',
#   'daban',
#   'presión',
#   'vacaciones',
#   'combates',
#   'muertos',
#   'pago',
#   'ilegítimamente',
#   'traslado',
#   'capturas',
#   'presentó',
#   'apoyo',
#   'reportó',
#   'presentadas',
#   'huila',
#   'administrativa',
#   'permisos',
#   'presentada',
#   'presentar',
#   'presentaron',
#   'importante',
#   'suárez',
#   'exigencia',
#   'tangibles',
#   'dando',
#   'exigía',
#   'presentados',
#   'muerto',
#   'reporta',
#   'reportaron',
#   'presentado',
#   'producción',
#   'guerrilleros',
#   'legítimamente',
#   'ilegítimas',
#   'mencionado',
#   'condicionada',
#   'obtención',
#   'previa',
#   'hojas',
#   'constitutivos',
#   'desapariciones',
#   'jesús',
#   'amado'],
#  'cluster 10': ['comandante',
#   'información',
#   'operaciones',
#   'brigada',
#   'inteligencia',
#   'hacía',
#   'ejército',
#   'unidades',
#   'general',
#   'comandantes',
#   'informe',
#   'hacían',
#   'misión',
#   'comando',
#   'grupos',
#   'pelotones',
#   'daba',
#   'jefe',
#   'programas',
#   'gaula',
#   'control',
#   'batallones',
#   'b',
#   'programa',
#   'documento',
#   'órdenes',
#   'informaciones',
#   'nivel',
#   'realmente',
#   'táctica',
#   'documentos',
#   'instrucción',
#   'llegar',
#   'radio',
#   'llama',
#   'compañías',
#   'tropa',
#   'encargado',
#   'pasar',
#   'frente',
#   'división',
#   'abrigada',
#   'policía',
#   'llegaba',
#   'ejecutivo',
#   'magdalena',
#   'funciones',
#   'cargo',
#   'firma',
#   'enemigo',
#   'c',
#   'recibió',
#   'tropas',
#   'oficina',
#   'contraguerrillas',
#   'informantes',
#   'radiales',
#   'comunicación',
#   'tácticas',
#   'recibe',
#   'reunión',
#   'comante',
#   'torres',
#   'base',
#   'manejaba',
#   'guías',
#   'planeamiento',
#   'anexo',
#   'escuchaba',
#   'misiones',
#   'militares',
#   'patrullaje',
#   'actividades',
#   'delta',
#   'fuerzas',
#   'das',
#   'analista',
#   'análisis',
#   'plan',
#   'paramilitares',
#   'terreno',
#   'cuáles',
#   'frecuencia',
#   'esté',
#   'mío',
#   'tenente',
#   'función',
#   'seguramente',
#   'recibía',
#   'mis',
#   'reuniones',
#   'tuviera',
#   'ordena',
#   'debía',
#   'estuviera',
#   'potestad',
#   'instrucciones',
#   'línea',
#   'abajo',
#   'brigadas',
#   'red',
#   'cooperantes',
#   'común',
#   'montoya',
#   'supuestamente',
#   'puntual',
#   'ciclo',
#   'boletín',
#   'datos',
#   'recompensa',
#   'fuente',
#   'recompensas',
#   'fuentes',
#   'verificar',
#   'precisa',
#   'seguimiento',
#   'campaña',
#   'carepa',
#   'agregados',
#   'operacionalmente',
#   'integrante',
#   'acosta',
#   'dirección',
#   'ilegales',
#   'margen',
#   'd',
#   'carpeta',
#   'celular',
#   'henry',
#   'vincularse',
#   'jueces',
#   'expectativas',
#   'urbanas',
#   'bienestar',
#   'delincuencia',
#   'víctor',
#   'turbo'],
#  'cluster 11': ['obligaciones',
#   'judicial',
#   'intervención',
#   'régimen',
#   'explicación',
#   'medina',
#   'funcionarios'],
#  'cluster 12': ['logro',
#   'otorguen',
#   'estable',
#   'adoptar',
#   'autorización',
#   'país',
#   'anticipada',
#   'transitoria',
#   'beneficiario'],
#  'cluster 13': ['levantamiento', 'cti', 'cuerpo'],
#  'cluster 14': ['pérez', 'política', 'ramón', 'ramon', 'democrática'],
#  'cluster 15': ['pardo',
#   'territorial',
#   'urabá',
#   'hernán',
#   'construcción',
#   'individual',
#   'aplicando',
#   'busca',
#   'armonización',
#   'razonabilidad'],
#  'cluster 16': ['único',
#   'oportunidad',
#   'presencia',
#   'reconocimiento',
#   'ley',
#   'directa',
#   'búsqueda',
#   'informes',
#   'declarar',
#   'conflicto',
#   'literal',
#   'voluntarias',
#   'conocido',
#   'determinación',
#   'comillas',
#   'armados',
#   'practicará',
#   'pariente',
#   'jurídica',
#   'señala',
#   'indicado',
#   'notificará',
#   'ocurrencia',
#   'completo',
#   'voluntariamente',
#   'escrito',
#   'defensor',
#   'reguladas',
#   'voluntario',
#   'rendirla',
#   'negar',
#   'puestos',
#   'obligado',
#   'organizaciones',
#   'interno',
#   'ocasión',
#   'dadas',
#   'previamente',
#   'disposición',
#   'corrió',
#   'compañero',
#   'carecen',
#   'advertirá',
#   'contenido',
#   'cónyuge',
#   'reconoce'],
#  'cluster 17': ['coral',
#   'escalante',
#   'capera',
#   'nacimiento',
#   'pertenece',
#   'william',
#   'étnico',
#   'miembro'],
#  'cluster 18': ['fuerza',
#   'normatividad',
#   'agentes',
#   'acuden',
#   'conjunta',
#   'rápido',
#   'oro',
#   'trasladada',
#   'procederemos',
#   'efectos']}

# %%
PromptInicio = [
    'A partir del diccionario de clusters de palabras proporcionado, identifica el tema o tópico principal que mejor represente a cada cluster.',
    'Recuerda que las palabras en cada cluster fueron obtenidas mediante un método de agrupamiento basado en una red de bigramas extraídos de descripciones de videos de YouTube sobre el Caso 03 de la JEP.',
    'Las palabras están ordenadas de mayor a menor relevancia dentro de cada cluster, y reflejan conceptos clave en torno a ejecuciones extrajudiciales, víctimas, agentes del Estado y el contexto del conflicto armado en Colombia.'
]

PromptFinal = [
    'Al momento de devolver los datos contesta con el siguiente formato: Numerodecluster:[dato] TemaoTopicoPrincipal:[dato]',
    'Solo contesta con el formato suministrado. Ten en cuenta que los datos provienen de descripciones de videos sobre crímenes de Estado en el marco del Caso 03 de la JEP.'
]


# Constructing the request by joining prompts, dictionary, and final prompts
request = " ".join(PromptInicio) + str(diccionario) + " ".join(PromptFinal)

# %%
request
# Out:
# "A partir del diccionario de clusters de palabras proporcionado, identifica el tema o tópico principal que mejor represente a cada cluster. Recuerda que las palabras en cada cluster fueron obtenidas mediante un método de agrupamiento basado en una red de bigramas extraídos de descripciones de videos de YouTube sobre el Caso 03 de la JEP. Las palabras están ordenadas de mayor a menor relevancia dentro de cada cluster, y reflejan conceptos clave en torno a ejecuciones extrajudiciales, víctimas, agentes del Estado y el contexto del conflicto armado en Colombia.{'cluster 1': ['tarea', 'material', 'auxiliar', 'omega', 'negro', 'intendencia', 'martínez', 'fabián', 'gerardo', 'céspedes'], 'cluster 2': ['relación', 'responsabilidad', 'civil', 'contacto', 'grado', 'integrantes', 'participó', 'nacional', 'población', 'bles', 'aducir', 'participaron', 'indirecta', 'causa', 'conductas', 'circunstancias', 'aceptación', 'libre', 'ausencia', 'protección', 'pública', 'existieron', 'miembros', 'colombia', 'indirectamente', 'determina', 'amnistia', 'detallado', 'estipulado', 'exhaustivo', 'adelantarse', 'asimismo', 'pondrá', 'reconozca'], 'cluster 3': ['dinero', 'cuarto', 'soto', 'autoría', 'reservados', 'consanguineidad', 'consanguinidad', 'gustavo', 'afinidad', 'partida', 'montaña'], 'cluster 4': ['número', 'superior', 'profesional', 'gobierno', 'despacho', 'virtud', 'abogado', 'infórmenos', 'movilidad', 'cédula', 'tarjeta', 'órgano', 'ciudad', 'identificado', 'convocado', 'bogotá', 'ciudadanía', 'consejo', 'portador', 'aprobó', 'rameli', 'fundación', 'corporación', 'quejada', 'identificarse', 'alejandro', 'privado', 'identifico', 'identificada', 'judicatura', 'vertical', 'futuros', 'afirmativo', 'arteaga', 'adscrito', 'forjando'], 'cluster 5': ['día', 'caso', 'días', 'pregunta', 'víctimas', 'quiero', 'perdón', 'versión', 'preguntas', 'rodríguez', 'mañana', 'diligencia', 'noche', 'respuesta', 'hora', 'audiencia', 'compareciente', 'público', 'llegamos', 'marco', 'presente', 'representante', 'propósito', 'presentación', 'representación', 'libertad', 'registro', 'participación', 'receso', 'tarde', 'voluntaria', 'horas', 'saludo', 'procuraduría', 'presentes', 'magistrados', 'señores', 'continuamos', 'instalar', 'marzo', 'tardes', 'permito', 'definidos', 'representar', 'comparece', 'jep', 'rigurosa', 'equipo', 'verificado', 'asistentes', 'garcía', 'procuradora', 'pido', 'magistratura', 'camilo', 'semana', 'proceda', 'tr', 'amable', 'presenta', 'proteger', 'representantes', 'tribunal', 'sociedad', 'darle', 'armado', 'encuentran', 'continuar', 'carlos', 'comparecientes', 'ofrecer', 'vigente', 'defensa', 'apoderados', 'acreditadas', 'familiares', 'abogados', 'calidad', 'masacre', 'colegas', 'auto', 'rendir', 'continuación', 'suspende', 'reanudamos', 'renovamos', 'remitir', 'perfecto', 'hacerle', 'generales', 'temas', 'edgar', 'fidel', 'febrero', 'presidir', 'intervinientes', 'profundizar', 'agosto', 'damos', 'mayo', 'septiembre', 'virtual', 'confesión', 'media', 'escuchar', 'versiones', 'distinguidos', 'medalla', 'restaurativas', 'nación', 'terminada', 'guerrero', 'turno', 'andrés', 'énfasis', 'actores', 'dr', 'autónomo', 'sujetos', 'vargas'], 'cluster 6': ['especial', 'militar', 'proceso', 'especiales', 'curso', 'investigación', 'desarrollo', 'salí', 'justicia', 'penal', 'paz', 'procedimiento', 'artículo', 'toma', 'centro', 'investigaciones', 'cambio', 'derechos', 'objetivo', 'cumplimiento', 'incumpla', 'aporte', 'buscar', 'ordinaria', 'corte', 'comprometida', 'sugerir', 'delitos', 'contribuir', 'plena', 'decisiones', 'escuela', 'declaración', 'evaluadas', 'reparación', 'juzgado', 'juez', 'repetición', 'acto', 'perderá', 'razones', 'formación', 'prestar', 'prestando', 'prestó', 'ingresé', 'satisfacer', 'entender', 'requerimientos', 'medidas', 'atender', 'satisfacción', 'consagrado', 'código', 'llamado', 'acopio', 'copia', 'humanos', 'suficientes', 'pérdida', 'absoluta', 'renuncias', 'agrupación', 'esclarecimiento', 'disciplinaria', 'derecho', 'legis ...

# %%
request = request
chat_completion = openai.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": request,
        }
    ],
    model="gpt-4-1106-preview",
    max_tokens=2000,  # Increase the number of tokens allowed
    temperature=0.7,  # Reduce "creativity" to obtain precise responses
    top_p=1,  # Adjust maximum probability to ensure precise responses
)
respuesta = chat_completion.choices[0].message.content

# %%
print(respuesta)
# Out:
# Cluster1: Tareas y operaciones logísticas militares
# Cluster2: Responsabilidad y participación en el conflicto
# Cluster3: Finanzas y relaciones de autoría en el contexto militar
# Cluster4: Procesos y procedimientos judiciales
# Cluster5: Procesos judiciales y representación de las víctimas
# Cluster6: Marco legal y procesos de justicia especial
# Cluster7: Recuerdo y reconocimiento de operativos militares
# Cluster8: Vida y operaciones en unidades militares
# Cluster9: Resultados operacionales y presiones en el contexto militar
# Cluster10: Inteligencia, comando y control en operaciones militares
# Cluster11: Obligaciones y procesos judiciales
# Cluster12: Beneficios y condiciones de desmovilización
# Cluster13: Procedimientos forenses y levantamiento de cuerpos
# Cluster14: Política y democracia en el contexto del conflicto
# Cluster15: Territorio y construcción de paz
# Cluster16: Reconocimiento de responsabilidad y procesos de paz
# Cluster17: Identidad étnica y pertenencia en el contexto del conflicto
# Cluster18: Acciones y procedimientos de las fuerzas armadas

# %%
with open("clusters_theme.txt", "w", encoding="utf-8") as file:
    file.write(respuesta)
