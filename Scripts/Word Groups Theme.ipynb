# %% [markdown]
# # THEMES FOR WORD GROUPS USING OpenAI
#
# **Authors**
# - Alejandro Urrego Lopéz
# - Cesar Augusto Prieto Sarmiento
#
# This python notebook contains the development of the code with which using the AI to generate the main themes or topics for each word group generated by the best clustering algorithm.

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd   # For data manipulations
import numpy as np    # For maths
import igraph as ig   # For networks 
import openai        # AI implementations
from dotenv import load_dotenv

import os
load_dotenv()
# Hay que poner la apy key openai.api_key

# %%
data_folder_path = os.path.dirname(os.getcwd()) + os.sep + 'Outputs' + os.sep

# %%
# Definir la ruta del directorio de trabajo
directorio_trabajo = r'C:/Users/Pc/Desktop/-Proyecto-JEP-/Outputs/Skipgramas/Norte de Santander'

# Cambiar el directorio de trabajo
os.chdir(directorio_trabajo)

# %% [markdown]
# ## Development and research of topics

# %%
clusters = pd.read_csv('clusters_jep.txt')
clusters=clusters.sort_values(by='eigen', ascending=False)
clusters
# Out:
#             word  cluster         eigen
# 244     víctimas       23  1.000000e+00
# 14       ustedes       10  8.512448e-01
# 116     ejército       13  4.259053e-01
# 13        quiero       10  4.114493e-01
# 115          día       10  3.933411e-01
# ...          ...      ...           ...
# 2053      dígame        2  4.737818e-08
# 1346     matarle        8  2.817917e-08
# 1865  berraquera        2  1.492633e-08
# 1866    midiendo        2  1.492633e-08
# 614         azul        8  1.434219e-09
#
# [2332 rows x 3 columns]

# %%
diccionario = {}
for i in set(clusters['cluster']):
    diccionario['cluster '+str(i)] = clusters.query('cluster==@i')['word'].tolist()

# %%
diccionario
# Out:
# {'cluster 1': ['mí',
#   'vida',
#   'acuerdo',
#   'compromiso',
#   'positivos',
#   'derechos',
#   'marcha',
#   'impunidad',
#   'restaurativo',
#   'versiones',
#   'estatales',
#   'empezó',
#   'pase',
#   'empecé',
#   'operacionales',
#   'escuchó',
#   'internacional',
#   'jamás',
#   'secuestro',
#   'pechi',
#   'dejaba',
#   'cometimos',
#   'espero',
#   'perpetrados',
#   'conoció',
#   'comunidad',
#   'colaboraba',
#   'decisivos',
#   'conjuró',
#   'aceptar',
#   'pelotón',
#   'hayan',
#   'informes',
#   'manos',
#   'enorme',
#   'armado',
#   'afectadas',
#   'desenterrar',
#   'favorita',
#   'partecitas',
#   'mente',
#   'carpa',
#   'permitiera',
#   'honor',
#   'quedar',
#   'legal',
#   'obligados',
#   'justificara',
#   'transformó',
#   'entender',
#   'derecho',
#   'injustamente',
#   'invito',
#   'observaciones',
#   'devia',
#   'generaba',
#   'concluir',
#   'jornalero',
#   'llamados',
#   'fatales',
#   'humanitario',
#   'riguroso',
#   'llevaron',
#   'acusaciones',
#   'picada',
#   'reducir',
#   'padecido',
#   'tuvieron',
#   'barbarie',
#   'transicional',
#   'levantar',
#   'contrastación',
#   'indicadores',
#   'sacó',
#   'frutas',
#   'corte',
#   'pasando',
#   'titánica',
#   'queda',
#   'planeamiento',
#   'llegaron',
#   'doy',
#   'medi',
#   'competencia',
#   'ongs',
#   'vivíamos',
#   'ocurrir',
#   'instituciones',
#   'jesucristo',
#   'recibido',
#   'esfuerzos',
#   'colocaron',
#   'ponía',
#   'robó',
#   'fuente',
#   'tapaban',
#   'avivó',
#   'venga',
#   'ruta',
#   'recuperar',
#   'investigar',
#   'anteriores',
#   'devolverles',
#   'trazó',
#   'conformaban',
#   'rescatar',
#   'llenó',
#   'volvió',
#   'cuide',
#   'administrativa',
#   'dolores',
#   'manejar'],
#  'cluster 2': ['casa',
#   'muerto',
#   'reportaron',
#   'mentiras',
#   'dando',
#   'llevan',
#   'llevo',
#   'supuestamente',
#   'pensaba',
#   'sueños',
#   'asesinaron',
#   'llegaban',
#   'ah',
#   'arma',
#   'noche',
#   'líder',
#   'vivo',
#   'soldado',
#   'chamo',
#   'garantía',
#   'olvidarlo',
#   'cerquita',
#   'paró',
#   'hora',
#   'triste',
#   'gritar',
#   'comparecer',
#   'cobardemente',
#   'finca',
#   'agüita',
#   'vi',
#   'pare',
#   'camine',
#   'secuestrado',
#   'subieron',
#   'llevándolos',
#   'disparándoles',
#   'retenido',
#   'tarra',
#   'listo',
#   'patrullas',
#   'soldados',
#   'reclutado',
#   'decimos',
#   'paramilitarismo',
#   'íbamos',
#   'regaló',
#   'casas',
#   'pasaba',
#   'cercas',
#   'aportes',
#   'buscando',
#   'sueño',
#   'correr',
#   'caminamos',
#   'amarrado',
#   'justificación',
#   'extender',
#   'bombril',
#   'dormir',
#   'reconociendo',
#   'colchones',
#   'metidos',
#   'estuvieron',
#   'vereda',
#   'pita',
#   'agaron',
#   'mire',
#   'alargar',
#   'cayendo',
#   'agarraste',
#   'salieron',
#   'potreros',
#   'paré',
#   'galleta',
#   'sacudieron',
#   'afuera',
#   'sangre',
#   'cansado',
#   'asesinos',
#   'ilusión',
#   'sabíamos',
#   'esperándonos',
#   'engaños',
#   'pensé',
#   'reultado',
#   'acarí',
#   'bocado',
#   'tomara',
#   'bordo',
#   'use',
#   'largó',
#   'podía',
#   'hamaca',
#   'peg',
#   'amarrar',
#   'oiga',
#   'cagado',
#   'cortecito',
#   'regala',
#   'puros',
#   'quedo',
#   'fría',
#   'llevaban',
#   'esposado',
#   'modos',
#   'sangrero',
#   'llenaban',
#   'cuesten',
#   'atrás',
#   'dígame',
#   'berraquera',
#   'midiendo'],
#  'cluster 3': ['persona',
#   'dios',
#   'conocimiento',
#   'seleccionados',
#   'detrás',
#   'créame',
#   'peor',
#   'conflicto',
#   'inocentes',
#   'compartir',
#   'quitaron',
#   'inocente',
#   'cuerpo',
#   'trabajador',
#   'mató',
#   'indefensión',
#   'trabajadora',
#   'asesinamos',
#   'sigo',
#   'tomé',
#   'ganaba',
#   'homicidios',
#   'mal',
#   'huye',
#   'veían',
#   'enferma',
#   'causando',
#   'cambio',
#   'llevó',
#   'reportamos',
#   'arrepientan',
#   'millón',
#   'pendiente',
#   'humano',
#   'hombre',
#   'edad',
#   'atroces',
#   'asesinar',
#   'bendiga',
#   'acuerde',
#   'amando',
#   'querida',
#   'perdona',
#   'perdonarla',
#   'normal',
#   'decisiones',
#   'salud',
#   'martín',
#   'limonal',
#   'sobreprotector',
#   'alegría',
#   'acompáñenos',
#   'queríamos',
#   'arrebatarles',
#   'perdonamos',
#   'homicida',
#   'perdono',
#   'delito',
#   'debía',
#   'juzgarle',
#   'pídanle',
#   'deseo',
#   'abajo',
#   'confía',
#   'quedé',
#   'engañamos',
#   'agarraron',
#   'humilde',
#   'llevábamos',
#   'cantidad',
#   'desconfiados',
#   'peñaranda',
#   'ejecutor',
#   'generaciones',
#   'barrio',
#   'forjador',
#   'simulamos',
#   'garzón',
#   'sonrisa',
#   'dividió',
#   'dolorosas',
#   'empezamos',
#   'narrar',
#   'verida',
#   'atento',
#   'delincuente',
#   'cariñoso',
#   'cantante',
#   'solté',
#   'futuro',
#   'pedazo',
#   'final',
#   'cuántos',
#   'secuestramos',
#   'eterna',
#   'tranquilos',
#   'pensando',
#   'policía',
#   'darse',
#   'tomadas',
#   'vistieron',
#   'perdonará',
#   'vayan',
#   'dispuso',
#   'calisto',
#   'acompañaban',
#   'contagiaba',
#   'miedos',
#   'dañarlo',
#   'foros',
#   'esperanza',
#   'toman',
#   'escepticismo',
#   'puedan'],
#  'cluster 4': ['dejaron',
#   'arrastró',
#   'presidente',
#   'unidas',
#   'comisionada',
#   'agarré',
#   'prendas',
#   'repetirse',
#   'tragedias',
#   'vivir',
#   'verificación',
#   'programa',
#   'atraque',
#   'sentí',
#   'orgullo',
#   'brilla',
#   'cadáveres',
#   'incumpliendo',
#   'lcas'],
#  'cluster 5': ['sociedad',
#   'mundo',
#   'rol',
#   'cargo',
#   'marulanda',
#   'pasos',
#   'causamos',
#   'cumplimiento',
#   'viene',
#   'reuní',
#   'integral',
#   'iniciar',
#   'amigo',
#   'indiferente',
#   'muchísimo',
#   'tranquilo',
#   'aclararlo',
#   'esencial',
#   'volteo',
#   'enemigos',
#   'sepa',
#   'desborona',
#   'grado',
#   'adquiridos',
#   'autoridad',
#   'amable',
#   'preguntarlo',
#   'chogo',
#   'cti',
#   'familiar',
#   'salimos',
#   'sirvió',
#   'comprensivo',
#   'proyectos',
#   'respetuosa',
#   'pesitos',
#   'uniforme',
#   'querer',
#   'criterios',
#   'implantar',
#   'ramón',
#   'camuflado',
#   'absoluta',
#   'formación',
#   'implementar'],
#  'cluster 6': ['militar',
#   'central',
#   'estableció',
#   'servicio',
#   'ordinaria',
#   'pudieran',
#   'éxito',
#   'traigan',
#   'ocasiones',
#   'cargos',
#   'política',
#   've',
#   'suboficial',
#   'mencionado',
#   'seguí',
#   'decidí',
#   'prestar',
#   'expedientes',
#   'transcurso',
#   'instrucción',
#   'cerebro',
#   'enemigo',
#   'ingresé',
#   'desempleados',
#   'filas',
#   'reconstruir',
#   'operacional',
#   'procesos',
#   'medio',
#   'conteo',
#   'horrores',
#   'inoperancia',
#   'continué',
#   'laven',
#   'llamamiento',
#   'caído',
#   'indicador',
#   'conocido',
#   'utilizar',
#   'engrosar',
#   'calle',
#   'contacto',
#   'democrática',
#   'únicamente',
#   'tiró',
#   'mandó',
#   'carrera',
#   'discapacidad',
#   'aguanto',
#   'superó',
#   'voló',
#   'tarjetas'],
#  'cluster 7': ['grande',
#   'reconozco',
#   'queridos',
#   'abogados',
#   'devolver',
#   'soacha',
#   'sucedido',
#   'recinto',
#   'identidad',
#   'imagen',
#   'búsqueda',
#   'zonas',
#   'cuerpos',
#   'alegre',
#   'afinaron',
#   'piden',
#   'costa',
#   'hallándola',
#   'estadística',
#   'relacionaré',
#   'hermoso',
#   'especie',
#   'sientan',
#   'preparatorias',
#   'colectivo',
#   'mayores',
#   'pequeño',
#   'ponerme',
#   'reivindico',
#   'rescatarán',
#   'sometidos',
#   'equipo',
#   'desaparecidos',
#   'antropólogos',
#   'canadá',
#   'corporación',
#   'envían',
#   'institucional',
#   'reconstruyeron',
#   'involucradas',
#   'comenzar',
#   'dadas',
#   'cifras',
#   'encontrado',
#   'compartieron',
#   'acercó',
#   'rostro'],
#  'cluster 8': ['pasó',
#   'voz',
#   'tardes',
#   'urbano',
#   'diligencia',
#   'encuentran',
#   'abril',
#   'duele',
#   'ayudar',
#   'mañana',
#   'asiento',
#   'formaron',
#   'perdone',
#   'agricultura',
#   'víctima',
#   'sandra',
#   'sargento',
#   'limpio',
#   'pecado',
#   'pasaron',
#   'pasar',
#   'cayó',
#   'tarde',
#   'mauricio',
#   'llegué',
#   'alfonso',
#   'imputado',
#   'tiro',
#   'bu',
#   'partes',
#   'ingreso',
#   'plata',
#   'sacaron',
#   'prójimo',
#   'procesales',
#   'conrado',
#   'paramos',
#   'espere',
#   'psicólogos',
#   'especiales',
#   'asistentes',
#   'rafael',
#   'cara',
#   'citando',
#   'hitler',
#   'abogado',
#   'testigo',
#   'sentarse',
#   'ayudaran',
#   'abrieron',
#   'repito',
#   'levantaba',
#   'sangreo',
#   'ay',
#   'asegurado',
#   'reparen',
#   'llevárselo',
#   'llegando',
#   'iban',
#   'cogíamos',
#   'ejecución',
#   'navar',
#   'barbosa',
#   'laguna',
#   'miró',
#   'asustado',
#   'aeropuerto',
#   'criminalidad',
#   'pegaron',
#   'disparo',
#   'buscaron',
#   'hombro',
#   'llamé',
#   'brevemente',
#   'politólogos',
#   'económicamente',
#   'ventanita',
#   'todito',
#   'estuviéramos',
#   'arrecho',
#   'grite',
#   'selección',
#   'ayudarnos',
#   'persiguió',
#   'interdisciplinario',
#   'proyectil',
#   'estuviera',
#   'colectivos',
#   'uniformar',
#   'matarle',
#   'azul'],
#  'cluster 9': ['gobierno',
#   'reparación',
#   'jurídica',
#   'demandas',
#   'público',
#   'inscritas',
#   'pertenecer',
#   'casado',
#   'olvida',
#   'único',
#   'modalidad',
#   'lucha',
#   'plena',
#   'justo',
#   'haberle',
#   'expectativas',
#   'reincorporarse',
#   'armados',
#   'mejores',
#   'beneficios',
#   'oro',
#   'contento',
#   'encontramos',
#   'puso',
#   'particular',
#   'dados',
#   'origen',
#   'necesitan',
#   'sucesivas',
#   'dijera',
#   'cumberos',
#   'dispuesto',
#   'duda',
#   'activar',
#   'medida',
#   'resolver',
#   'extendió',
#   'problema',
#   'historias',
#   'seguimiento',
#   'presenciado',
#   'social',
#   'perfil',
#   'presionando',
#   'macr',
#   'cabeza',
#   'anhelo',
#   'seleccionadas',
#   'doloroso',
#   'reponer',
#   'tocan',
#   'agarraban',
#   'cercana',
#   'comité',
#   'esperar',
#   'agredidas',
#   'desaparece',
#   'haberlas',
#   'materializa',
#   'hací',
#   'lógica'],
#  'cluster 10': ['ustedes',
#   'quiero',
#   'día',
#   'señores',
#   'hijos',
#   'mis',
#   'dolor',
#   'daño',
#   'hijo',
#   'familiares',
#   'militares',
#   'seres',
#   'familias',
#   'magistrados',
#   'padre',
#   'corazón',
#   'perdón',
#   'familia',
#   'madres',
#   'pido',
#   'fácil',
#   'presentes',
#   'pedir',
#   'pregunta',
#   'acciones',
#   'esposos',
#   'causado',
#   'humanos',
#   'hermanos',
#   'daños',
#   'memoria',
#   'encuentro',
#   'reparar',
#   'respeto',
#   'padres',
#   'mensaje',
#   'institución',
#   'importante',
#   'muchacho',
#   'vuelva',
#   'madre',
#   'sentir',
#   'organizaciones',
#   'terminaron',
#   'agradezco',
#   'rabia',
#   'esposo',
#   'cabe',
#   'siento',
#   'niños',
#   'comunicación',
#   'presente',
#   'cuál',
#   'principales',
#   'palabras',
#   'sienten',
#   'viera',
#   'nexo',
#   'dieran',
#   'directas',
#   'amenaza',
#   'sabían',
#   'armamento',
#   'extrajudiciales',
#   'reflexiones',
#   'ánimo',
#   'estrato',
#   'capacidad',
#   'echen',
#   'resistencia',
#   'encubriendo',
#   'denuncian',
#   'apostando',
#   'proyecto',
#   'complot',
#   'arrebataron',
#   'colaborando',
#   'terror',
#   'poderlo',
#   'cabezas',
#   'limpiar',
#   'destino',
#   'papá',
#   'estudiar',
#   'ahorita',
#   'llevarlos',
#   'allí',
#   'je',
#   'tomar',
#   'perdonen',
#   'agarró',
#   'falta',
#   'sufrieron',
#   'titule',
#   'perdieron',
#   'dejar',
#   'paro',
#   'esposas',
#   'leonela',
#   'consiguieron',
#   'organismos',
#   'alma',
#   'pequeños',
#   'logrado',
#   'entreguen',
#   'compañeras',
#   'asesinarlos',
#   'éticos',
#   'explicación',
#   'rescate',
#   'ganas',
#   'querido',
#   'comunal',
#   'dejaban',
#   'pagan',
#   'recibiremos',
#   'negocio',
#   'reanuda',
#   'miraban',
#   'sacado',
#   'históricamente',
#   'diga',
#   'sancionar',
#   'actos',
#   'sanción',
#   'magistradas',
#   'siente',
#   'medios',
#   'pedirles',
#   'hacerle',
#   'sufrimiento',
#   'eco',
#   'quedaron',
#   'huérfanos',
#   'ayudó',
#   'darle',
#   'mami',
#   'mamás',
#   'pobres',
#   'universidades',
#   'territorio',
#   'hermanas',
#   'avergüenzo',
#   'iones',
#   'produjeran',
#   'cárcel',
#   'innecesarios',
#   'compañero',
#   'soledad',
#   'vivimos',
#   'impartir',
#   'quiso',
#   'asumiendo',
#   'experimentaron',
#   'gustavo',
#   'daba',
#   'dijeran',
#   'morales',
#   'mío',
#   'sur',
#   'vergüenza',
#   'limpien',
#   'autoridades',
#   'buscarme',
#   'dichas',
#   'regresar',
#   'recuperación',
#   'generó',
#   'relatores',
#   'cumpleaños',
#   'pérdida',
#   'sentimiento',
#   'escuchando',
#   'disculpas',
#   'sentimientos',
#   'pongan',
#   'tu',
#   'difícil',
#   'hubiera',
#   'ausencia',
#   'relato',
#   'conciencia',
#   'valentía',
#   'concebimos',
#   'defensoras',
#   'villamil',
#   'intervinientes',
#   'estn',
#   'darles',
#   'justificando',
#   'humana',
#   'desarrollar',
#   'visto',
#   'restaurar',
#   'problemas',
#   'represento',
#   'ocasión',
#   'acercado',
#   'acompaña',
#   'canoba',
#   'cae',
#   'saberlo',
#   'jurídico',
#   'llevamos',
#   'hirieron',
#   'veo',
#   'oviedo',
#   'prensa',
#   'memorias',
#   'escuchado',
#   'palomino',
#   'física',
#   'congreso',
#   'hernández',
#   'condiciones',
#   'sujetos',
#   'descanso',
#   'exigiendo'],
#  'cluster 11': ['responsabilidad',
#   'crímenes',
#   'país',
#   'reconocimiento',
#   'audiencia',
#   'justicia',
#   'comparecientes',
#   'asesinatos',
#   'frente',
#   'paz',
#   'auto',
#   'norte',
#   'especial',
#   'responsables',
#   'caso',
#   'humanidad',
#   'jep',
#   'encuentros',
#   'falsos',
#   'proceso',
#   'guerra',
#   'desapariciones',
#   'reconocer',
#   'cometí',
#   'pública',
#   'acepto',
#   'sistema',
#   'identificación',
#   'forzada',
#   'conductas',
#   'población',
#   'elemento',
#   'desaparición',
#   'repetición',
#   'venir',
#   'responsable',
#   'delitos',
#   'máximos',
#   'imputados',
#   'lesa',
#   'reconocimientos',
#   'marco',
#   'escrito',
#   'asesinato',
#   'municipios',
#   'procede',
#   'avanzar',
#   'protegida',
#   'asumir',
#   'tragedia',
#   'convocado',
#   'reconocieron',
#   'muertes',
#   'aportar',
#   'realidad',
#   'perjudicó',
#   'transforma',
#   'propósito',
#   'artículo',
#   'llamó',
#   'apuesta',
#   'deshonra',
#   'posición',
#   'determinó',
#   'paso',
#   'estatuto',
#   'judicial',
#   'habíamos',
#   'cometidos',
#   'cómplice',
#   'coautor',
#   'macrocasos',
#   'imputó',
#   'hubieran',
#   'ocurridos',
#   'omisión',
#   'causaron',
#   'completa',
#   'campanazo',
#   'título',
#   'antesala',
#   'decisión',
#   'agosto',
#   'abrir',
#   'reuniones',
#   'justificar',
#   'homicidio',
#   'preparación',
#   'principio',
#   'específicamente',
#   'tejido',
#   'penal',
#   'iglesa',
#   'aplicarán',
#   'establecer',
#   'primeras',
#   'graves',
#   'masivos',
#   'reconozca',
#   'ocurrido',
#   'decido',
#   'presenciar',
#   'promover',
#   'determinada',
#   'prueba',
#   'voluntariamente',
#   'irregulares',
#   'segmento',
#   'dimensiones',
#   'evitar',
#   'sistemática',
#   'reconozcan',
#   'restaurativa',
#   'liberar',
#   'manifestaron',
#   'quiénes',
#   'sincero',
#   'amigos',
#   'creer',
#   'recomponer',
#   'ampararon',
#   'colombianas',
#   'fuerzas',
#   'mundial',
#   'competir',
#   'dijimos',
#   'traza',
#   'mandato',
#   'crimen',
#   'camino',
#   'comillas',
#   'declarado',
#   'busca',
#   'cimienta',
#   'permitieron',
#   'enfoque',
#   'consolidación',
#   'responsabilidades',
#   'manifestaciones',
#   'detallada',
#   'don',
#   'dicha',
#   'evaluará',
#   'metodología',
#   'logró',
#   'breve',
#   'convocar',
#   'finales',
#   'ajustarlo',
#   'aplicamos',
#   'decirlo',
#   'garantías',
#   'generosidad',
#   'luchado',
#   'creímos',
#   'brillo',
#   'umbral',
#   'escenario',
#   'precisamente',
#   'sub',
#   'activó',
#   'abordar',
#   'escritos',
#   'constituyen',
#   'restaurativos',
#   'índices',
#   'explicaciones',
#   'presentadas',
#   'estudios',
#   'construcción',
#   'estados',
#   'apoyo',
#   'dialógico',
#   'vuelvo',
#   'detalle',
#   'reivindicar',
#   'preguntas',
#   'consideraba',
#   'concordancia',
#   'sanciones',
#   'jef',
#   'requiere',
#   'aplicación',
#   'podido',
#   'histórico',
#   'territorios',
#   'retuviereis',
#   'tribunal',
#   'voluntarias',
#   'privados',
#   'ratificaron',
#   'rompieron',
#   'roma',
#   'efectos',
#   'ordenó',
#   'generalizado',
#   'organización',
#   'cometieron',
#   'dea',
#   'concepto',
#   'código',
#   'miembro',
#   'identificadas',
#   'libre',
#   'entereza',
#   'preparar',
#   'convocó',
#   'dirigirse',
#   'sacar',
#   'finalmente',
#   'penalmente',
#   'trató',
#   'ampliaron',
#   'vivido',
#   'calificación',
#   'magnitud',
#   'cometieran',
#   'determinadas',
#   'autor',
#   'convocados',
#   'voluntaria',
#   'sumo',
#   'imposición',
#   'señalan',
#   'comete',
#   'honorable',
#   'numeral',
#   'intervenciones',
#   'execrables',
#   'continuemos',
#   'exhaustiva',
#   'apareció',
#   'levantamiento',
#   'dispersa',
#   'motivos',
#   'abriendo',
#   'confesión',
#   'juzgado',
#   'distorsionada',
#   'suyos',
#   'producto',
#   'instituto',
#   'destruyó',
#   'octavo',
#   'dialogar',
#   'americanos',
#   'respondieron',
#   'deciden',
#   'decide',
#   'plan',
#   'fronteras',
#   'aquello'],
#  'cluster 12': ['dignidad',
#   'imposible',
#   'coraje',
#   'sentido',
#   'decirles',
#   'jaimes',
#   'concentran',
#   'tarea',
#   'millones',
#   'reconstrucción',
#   'colombianos',
#   'labrando',
#   'firma',
#   'colectiva',
#   'tranquilidad',
#   'construir',
#   'consecuencias',
#   'repare',
#   'ofrecerles',
#   'lamento',
#   'indican',
#   'inalcanzable',
#   'negligencia',
#   'egado',
#   'resiliencia',
#   'villegas',
#   'reportadas',
#   'salí',
#   'violencia',
#   'josel',
#   'testimonio',
#   'william',
#   'gerardo',
#   'maira',
#   'merced',
#   'ineficiencia',
#   'prolongó',
#   'principios',
#   'repararlas',
#   'samuel',
#   'estatal'],
#  'cluster 13': ['ejército',
#   'santander',
#   'general',
#   'ocaña',
#   'miembros',
#   'brigada',
#   'comandante',
#   'resultados',
#   'unidad',
#   'jóvenes',
#   'bogotá',
#   'criminal',
#   'participó',
#   'número',
#   'batallón',
#   'nacional',
#   'ciudad',
#   'época',
#   'muchachos',
#   'oficial',
#   'operaciones',
#   'distinguen',
#   'estructura',
#   'tienda',
#   'carretero',
#   'judiciales',
#   'unidades',
#   'civiles',
#   'vacíos',
#   'defensa',
#   'bajas',
#   'compañeros',
#   'forzadas',
#   'patrón',
#   'mando',
#   'inteligencia',
#   'montoya',
#   'asesinados',
#   'oficiales',
#   'disposición',
#   'bucaramanga',
#   'infantería',
#   'análisis',
#   'febrero',
#   'agarrar',
#   'francisco',
#   'confabularon',
#   'noviembre',
#   'república',
#   'delesa',
#   'plenamente',
#   'subcase',
#   'división',
#   'confiaban',
#   'rojas',
#   'vino',
#   'entrenando',
#   'confesó',
#   'manzanas',
#   'matarlo',
#   'subalternos',
#   'exmiembros',
#   'engañados',
#   'paula',
#   'delincuentes',
#   'presiones',
#   'reclutador',
#   'cédula',
#   'características',
#   'colectivas',
#   'motivaciones',
#   'consolidada',
#   'subc',
#   'muertos',
#   'desempeñé',
#   'supo',
#   'problemática',
#   'arauca',
#   'cometido',
#   'mejorar',
#   'salgo',
#   'perdieran',
#   'mentimos',
#   'agentes',
#   'comando',
#   'traía',
#   'común',
#   'padilla',
#   'idea',
#   'provenían',
#   'llega',
#   'realizaron',
#   'jefe',
#   'ministro',
#   'ovidio',
#   'illo',
#   'cortés',
#   'engañé',
#   'documentos',
#   'entregué',
#   'vo',
#   'patrulla',
#   'fomentando',
#   'presentaran',
#   'diera',
#   'campesinas',
#   'falsas',
#   'tercero',
#   'engañaran',
#   'trasladados',
#   'reductos',
#   'ciudades',
#   'comandantes',
#   'atribuibles',
#   'b',
#   'condición',
#   'junio',
#   'contraguerrillas',
#   'programas',
#   'banda',
#   'encargado',
#   'meteoro',
#   'gamarra',
#   'hablado',
#   'exigencia',
#   'coordinación',
#   'rango',
#   'imaginé',
#   'concretan',
#   'oficinas',
#   'compañía',
#   'tarjeta',
#   'defensoría',
#   'existía',
#   'pertenecían',
#   'pequeña',
#   'identificando',
#   'terceros',
#   'protegerlas',
#   'modalidades',
#   'entidades',
#   'testimonios',
#   'engañarlos',
#   'recuperada',
#   'interior',
#   'trayendo',
#   'encontraba',
#   'nivel',
#   'llegan',
#   'reclutaba',
#   'nombran',
#   'sección',
#   'vial',
#   'integrantes',
#   'identificados',
#   'asesinaran',
#   'campo',
#   'legalidad',
#   'santa',
#   'escuadra',
#   'responder',
#   'cumplir',
#   'funciones',
#   'facilitando',
#   'facto',
#   'intermedio',
#   'quedaran',
#   'imputaciones',
#   'adscrita',
#   'identificarse',
#   'brin',
#   'malos',
#   'presentación',
#   'presentarlos',
#   'viajes',
#   'ilegítimamente',
#   'afortunadamente',
#   'ejerciendo',
#   'señalando',
#   'preguntaron',
#   'seleccionó',
#   'denunció',
#   'distintas',
#   'distintos',
#   'contratación',
#   'pronunciaron',
#   'acepté',
#   'llamando',
#   'contribuí',
#   'universidad',
#   'bán',
#   'contar',
#   'descubrí',
#   'condecoraciones',
#   'constante',
#   'septiembre',
#   'sains',
#   'manuel',
#   'legalizó',
#   'respectivamente',
#   'sepan',
#   'órgano',
#   'formara',
#   'expedida',
#   'delincuencial',
#   'ubicaran',
#   'jugar',
#   'clara',
#   'arrepentidos',
#   'instancia',
#   'macabro'],
#  'cluster 14': ['nombres',
#   'asesinadas',
#   'carga',
#   'permitido',
#   'obligaron',
#   'sufridos',
#   'negra',
#   'supuestos',
#   'vende',
#   'coca',
#   'fachada',
#   'intimidad',
#   'elaboro',
#   'sembrar',
#   'máscara',
#   'julano',
#   'razón',
#   'evolución',
#   'plátano',
#   'horas',
#   'atrocidades',
#   'criminales',
#   'amplíen',
#   'patrones',
#   'capturado',
#   'lero',
#   'empiezo',
#   'físicos',
#   'supieran',
#   'dilema',
#   'roja',
#   'dinámicas',
#   'lejos'],
#  'cluster 15': ['días',
#   'sé',
#   'cabo',
#   'álvaro',
#   'fernando',
#   'pronto',
#   'doña',
#   'joven',
#   'quintero',
#   'noticia',
#   'coronel',
#   'guillermo',
#   'intervención',
#   'maría',
#   'municipio',
#   'traer',
#   'verano',
#   'posibilidad',
#   'reyes',
#   'antonio',
#   'alexander',
#   'oficina',
#   'herrera',
#   'elías',
#   'jesús',
#   'encontré',
#   'rodríguez',
#   'gómez',
#   'suárez',
#   'rincón',
#   'jacome',
#   'llamaba',
#   'tamayo',
#   'teniente',
#   'rivera',
#   'garita',
#   'eduardo',
#   'carlos',
#   'garcía',
#   'muñoz',
#   'retirado',
#   'emilio',
#   'garcera',
#   'becerra',
#   'castillo',
#   'hija',
#   'méndez',
#   'levanto',
#   'fernel',
#   'adriana',
#   'gladis',
#   'id',
#   'rvz',
#   'stre',
#   'leyendo',
#   'fernanda',
#   'adelina',
#   'rodrí',
#   'mar',
#   'vz',
#   'ra',
#   'pedro',
#   'cu',
#   'nubia',
#   'capitán',
#   'jaime',
#   'ayude',
#   'prostíbulo',
#   'consume',
#   'navarro',
#   'chinchilla',
#   'ocupó',
#   'andrés',
#   'pérez',
#   'mora',
#   'peña',
#   'maldonado',
#   'descanta',
#   'descargaron',
#   'teléfono',
#   'comitiva',
#   'ariel',
#   'guerrero',
#   'amado',
#   'tamallo',
#   'armando',
#   'necesito',
#   'martínez',
#   'alberto',
#   'castro',
#   'calixto',
#   'vélez',
#   'darío',
#   'alt',
#   'diego',
#   'fajardo',
#   'botello',
#   'romero',
#   'jiménez',
#   'amparo',
#   'quintana',
#   'consuelo',
#   'ortega',
#   'espejos',
#   'igualmente',
#   'chaparro',
#   'luis',
#   'ángel',
#   'wilfredo',
#   'orlando',
#   'atroz',
#   'hoyos',
#   'jorgen',
#   'albeiro',
#   'burdel',
#   'santos',
#   'rea',
#   'activa',
#   'aponte',
#   'alazar',
#   'procedemos',
#   'dasa',
#   'hermana',
#   'gabriel',
#   'ever',
#   'ortiz',
#   'curso',
#   'víctor',
#   'botell',
#   'rubén',
#   'elkin',
#   'miranda',
#   'londoño',
#   'vengo',
#   'durán',
#   'personero',
#   'medina',
#   'juan',
#   'profesional',
#   'sandro',
#   'quitarme',
#   'daladier',
#   'dalad',
#   'reconoce',
#   'reserva',
#   'saavedra',
#   'jorge',
#   'jair',
#   'garay',
#   'desapareció',
#   'zoraida',
#   'palacios',
#   'tejada',
#   'tod',
#   'blanco',
#   'giraldo',
#   'ramiro',
#   'acto',
#   'miguel',
#   'belandia',
#   'jaqueline',
#   'chona',
#   'montaron',
#   'arias',
#   'capturaron',
#   'sánchez',
#   'forero',
#   'mosquera',
#   'daniel',
#   'cañizales',
#   'alfredo',
#   'marín',
#   'rubio',
#   'ríos',
#   'reivindiquen',
#   'sandoval',
#   'gonzález',
#   'sarita',
#   'pava',
#   'bermúdez',
#   'cecilia',
#   'diomar',
#   'amaya',
#   'raúl',
#   'porras',
#   'superior',
#   'lozano',
#   'adscrito',
#   'viviendo',
#   'carrascal',
#   'ezequiel',
#   'carvajal',
#   'fa'],
#  'cluster 16': ['personas',
#   'colombia',
#   'políticas',
#   'seguir',
#   'grupo',
#   'duro',
#   'malas',
#   'culpa',
#   'esclarecimiento',
#   'proporcionando',
#   'ley',
#   'quede',
#   'encontrar',
#   'ensuciamos',
#   'claro',
#   'contribuyó',
#   'quité',
#   'carretera',
#   'mataba',
#   'séptimo',
#   'preparó',
#   'estremecedor',
#   'mantenía',
#   'aportaron',
#   'desaparecidas',
#   'vulnerabilidad',
#   'solicitado',
#   'activas',
#   'flor',
#   'asesoramiento',
#   'trabajando',
#   'buscaban',
#   'naciones',
#   'misión',
#   'transitaremos',
#   'entero',
#   'niño',
#   'fallé',
#   'directo',
#   'seguirlo',
#   'espada',
#   'llené',
#   'lier',
#   'euclides',
#   'vega',
#   'viciosos',
#   'volví',
#   'desarrollo',
#   'alta',
#   'añitos',
#   'álvarez',
#   'expendedores',
#   'expendedor'],
#  'cluster 17': ['hermano',
#   'digo',
#   'lista',
#   'hablar',
#   'muerte',
#   'combate',
#   'campesino',
#   'mamá',
#   'guerrillero',
#   'carmen',
#   'digan',
#   'gutiérrez',
#   'entregaron',
#   'altos',
#   'participaron',
#   'asesin',
#   'fuerza',
#   'escuchar',
#   'lleve',
#   'peñuela',
#   'eugenia',
#   'javier',
#   'asesinado',
#   'iba',
#   'mujer',
#   'guerrilleros',
#   'orgánico',
#   'golpeaba',
#   'cuidar',
#   'teníamos',
#   'relojito',
#   'tiraban',
#   'concentra',
#   'arrebat',
#   'recordamos',
#   'ejecuté',
#   'guerrilla',
#   'muela',
#   'néstor',
#   'mandos',
#   'libreta',
#   'estábamos',
#   'wilmer',
#   'podían',
#   'cruelmente',
#   'quita',
#   'resultado',
#   'pedían',
#   'reunión',
#   'formé',
#   'radio',
#   'siquiera',
#   'pelotones',
#   'esparta',
#   'paradero',
#   'continuación',
#   'alex',
#   'esclarezcan',
#   'montarle',
#   'barrientos',
#   'psiquiátrico',
#   'cuento',
#   'olvidar',
#   'justifican',
#   'leonardo',
#   'cementerio',
#   'procesados',
#   'cambios',
#   'encontrábamos',
#   'laboré',
#   'plomacera',
#   'presionarla',
#   'fotos',
#   'presionar',
#   'colaborarle',
#   'vallena',
#   'llegaba',
#   'ponerles',
#   'presentaban',
#   'planeación',
#   'menor',
#   'principal',
#   'manchar',
#   'marihuana',
#   'presentarlo',
#   'falsamente',
#   'términos',
#   'falsa',
#   'ascanio',
#   'bandido',
#   'consiguiente',
#   'llegue',
#   'mercado',
#   'chico',
#   'video',
#   'hagan',
#   'combatiente',
#   'balaguera',
#   'caminando',
#   'dolía',
#   'azcanio',
#   'operandi',
#   'debían',
#   'exijo',
#   'habló',
#   'nestor',
#   'exigían',
#   'embarazo',
#   'estudiantes',
#   'melo',
#   'entro',
#   'dimiro',
#   'técnica',
#   'comprometí',
#   'repita',
#   'contreras',
#   'esfuerzo',
#   'incluido',
#   'bautista',
#   'llama',
#   'imagínese',
#   'bajó',
#   'celular',
#   'figueroa',
#   'munición',
#   'cita',
#   'destruir',
#   'empataron',
#   'arrecha',
#   'aprovechó',
#   'pulgadas',
#   'conseguido',
#   'sacaran',
#   'sacarse',
#   'uparela',
#   'pensábamos',
#   'drogas',
#   'velázquez',
#   'leal',
#   'pesos',
#   'ávila',
#   'presentado',
#   'torturaron',
#   'claudia',
#   'bicicleta',
#   'bernal',
#   'herm',
#   'definitivamente',
#   'mm',
#   'montarlo',
#   'pamir',
#   'sentía',
#   'droga',
#   'joel',
#   'ayuden',
#   'bobito',
#   'colocó',
#   'fondo',
#   'cuchilla',
#   'ametralladora',
#   'guamalito',
#   'quemaron',
#   'expendedoras',
#   'poncho',
#   'líquidos',
#   'póngase'],
#  'cluster 18': ['existió',
#   'rural',
#   'recibió',
#   'denuncias',
#   'escritas',
#   'enteró',
#   'perpetración'],
#  'cluster 19': ['paulino',
#   'libros',
#   'damos',
#   'acreditadas',
#   'órdenes',
#   'salazar',
#   'civil',
#   'coronado',
#   'coroneles',
#   'díaz',
#   'procuraduría',
#   'máximo',
#   'dispuestos',
#   'criterio',
#   'parra',
#   'odio',
#   'hablan',
#   'presentó',
#   'rameli',
#   'gáz',
#   'conoce',
#   'cito',
#   'ataque',
#   'brigadier',
#   'perdonemos',
#   'contó',
#   'afirmar',
#   'llegado',
#   'informe',
#   'suboficiales',
#   'calidad',
#   'remitidos',
#   'estén',
#   'sistemático',
#   'controles',
#   'afectación',
#   'asim',
#   'mandaría',
#   'colega',
#   'oí',
#   'analizaron',
#   'correlator',
#   'alejandra',
#   'nación',
#   'recurso',
#   'decisivo',
#   'función',
#   'radiografía',
#   'alejandro',
#   'santiago',
#   'escenas',
#   'pago',
#   'abro',
#   'futuros',
#   'policías',
#   'lady',
#   'fiscal',
#   'fases'],
#  'cluster 20': ['oportunidad',
#   'silencio',
#   'esclarecer',
#   'satisfacer',
#   'profundo',
#   'proteger',
#   'empezar',
#   'amenazas',
#   'buscar',
#   'afronte',
#   'sentencias',
#   'pudieron',
#   'acabar',
#   'hoja',
#   'conozcan',
#   'desgracia',
#   'empieza',
#   'frustración',
#   'nacer',
#   'décadas',
#   'comprender',
#   'negligente',
#   'dignificar',
#   'honra',
#   'fueran',
#   'restituir',
#   'consejo',
#   'seguiremos',
#   'indolente',
#   'materiales',
#   'relaciones',
#   'vinieron',
#   'vulnerados',
#   'desastre',
#   'conozca',
#   'histórica',
#   'cesar',
#   'patrimonio',
#   'judicatura',
#   'venezuela'],
#  'cluster 21': ['daban',
#   'hacía',
#   'esposa',
#   'perdí',
#   'tiros',
#   'trajeron',
#   'murió',
#   'brazo',
#   'vivieron',
#   'partícipes',
#   'habido',
#   'pensaron',
#   'semana',
#   'estando',
#   'buscan',
#   'puerta',
#   'u',
#   'capaz',
#   'croc',
#   'escucharon',
#   'nervios',
#   'piso',
#   'regáleme',
#   'alumbraron',
#   'planeaba',
#   'bajaron',
#   'rematar',
#   'cogió',
#   'bocabajo',
#   'tiraron',
#   'privado',
#   'gustó',
#   'aguantado',
#   'caí',
#   'mandaba',
#   'completo',
#   'vaino',
#   'pude',
#   'ayúdeme',
#   'hueso',
#   'haban',
#   'partido',
#   'conseguían',
#   'siguen',
#   'frontera',
#   'volvieron',
#   'conocía',
#   'acaban',
#   'n',
#   'empatado',
#   'anduviera',
#   'búsqueme',
#   'papeles',
#   'cabulla',
#   'poquita',
#   'acabado',
#   'atropellos',
#   'llorando',
#   'protegidos',
#   'espado',
#   'quizás',
#   'quiz'],
#  'cluster 22': ['tierra',
#   'mano',
#   'miedo',
#   'querían',
#   'agua',
#   'sabía',
#   'mataron',
#   'vaina',
#   'teatro',
#   'tomaron',
#   'positivo',
#   'pistola',
#   'aguacero',
#   'llevaba',
#   'comer',
#   'fusil',
#   'recuerdo',
#   'deja',
#   'tildaron',
#   'cañito',
#   'herida',
#   'pensar',
#   'aprecio',
#   'callos',
#   'plantas',
#   'maquin',
#   'llegamos',
#   'conozco',
#   'caña',
#   'llena',
#   'falso',
#   'supuesto',
#   'correctas',
#   'hallaría',
#   'berraca',
#   'derecha',
#   'compate',
#   'actores',
#   'bajaba',
#   'darme',
#   'izquierda',
#   'grave',
#   'arribita',
#   'disparaban',
#   'pongo',
#   'cariño',
#   'criar',
#   'protegiéndome',
#   'taré',
#   'plagos',
#   'casita',
#   'dejen',
#   'morirse',
#   'soñador',
#   'preguntaría',
#   'conmigo',
#   'estó',
#   'tardísimo',
#   'patearon',
#   'llamado',
#   'mandado',
#   'empuñe',
#   'bestia',
#   'comidita',
#   'hender',
#   'mental',
#   'pimpinas',
#   'consideración',
#   'perro',
#   'duerme',
#   'aire',
#   'víveres',
#   'salía',
#   'linterna',
#   'rosado',
#   'cogí',
#   'empuño',
#   'bonita',
#   'merecía',
#   'intentando',
#   'desempeñaba',
#   'coloqué',
#   'dita',
#   'soltaron',
#   'ganadera',
#   'lindas'],
#  'cluster 23': ['víctimas',
#   'catatumbo',
#   'campesinos',
#   'orden',
#   'dónde',
#   'suacha',
#   'región',
#   'hombres',
#   'representantes',
#   'llegar',
#   'trabajadores',
#   'colombiano',
#   'persistencia',
#   'regiones',
#   'situación',
#   'cúcuta',
#   'manchamos',
#   'perdonar',
#   'historia',
#   'acabe',
#   'declaraciones',
#   'internacionales',
#   'saludo',
#   'periodo',
#   'comisión',
#   'representación',
#   'opinión',
#   'compromisos',
#   'combates',
#   'presión',
#   'solución',
#   'macrocriminalidad',
#   'asumo',
#   'pie',
#   'participación',
#   'mujeres',
#   'viva',
#   'saquen',
#   'garantizar',
#   'ayuda',
#   'limpieza',
#   'señoras',
#   'gubernamentales',
#   'reconociera',
#   'departamentos',
#   'permitió',
#   'consensuó',
#   'venían',
#   'deberían',
#   'compareciente',
#   'personal',
#   'bloque',
#   'departamento',
#   'debieron',
#   'individuales',
#   'simular',
#   'transportadores',
#   'psicológicos',
#   'olvido',
#   'registro',
#   'iniciativas',
#   'coordinando',
#   'justamente',
#   'permite',
#   'satisfacción',
#   'escucharemos',
#   'trasladarlas',
#   'inquietudes',
#   'respetuoso',
#   'medidas',
#   'componente',
#   'registradas',
#   'aceptados',
#   'defraud',
#   'pueblo',
#   'comida',
#   'fenómeno',
#   'tenían',
#   'confiar',
#   'baja',
#   'colaboradores',
#   'trasladado',
#   'zona',
#   'armas',
#   'emprendieron',
#   'grupos',
#   'entregó',
#   'desaparecer',
#   'hicimos',
#   'lugares',
#   'nororiente',
#   'despensa',
#   'venía',
#   'especialmente',
#   'produce',
#   'ilegales',
#   'presentados',
#   'escuchaba',
#   'vio',
#   'fragmentada',
#   'aislados',
#   'necesario',
#   'pondrá',
#   'guerrillera',
#   'habiendo',
#   'líderes',
#   'investigación',
#   'centro',
#   'dañamos',
#   'reúne',
#   'experimentado',
#   'mostrar',
#   'engañado',
#   'área',
#   'mayoría',
#   'quean',
#   'finalidad',
#   'aguachica',
#   'presento',
#   'crecer',
#   'permitirá',
#   'estigmatización',
#   'pavón',
#   'cristalizados',
#   'puertas',
#   'cuidado',
#   'basa',
#   'indagatoria',
#   'habitantes',
#   'elman',
#   'tuve',
#   'paramilitares',
#   'contactos',
#   'mala',
#   'experto',
#   'conocí',
#   'urabá',
#   'sanar',
#   'áreas',
#   'laboriosos',
#   'individual',
#   'olvidados',
#   'comunidades',
#   'can',
#   'procedan',
#   'honorables',
#   'subos',
#   'elaborara',
#   'escuchará',
#   'vimos',
#   'matando',
#   'paramilitar',
#   'narrando',
#   'emprendedores',
#   'reporta',
#   'cicatrizar',
#   'entregadas',
#   'coordina',
#   'facilitó',
#   'cascudos',
#   'hacían',
#   'agricultores',
#   'posterioridad',
#   'antemano',
#   'cuya',
#   'impactos',
#   'accidental',
#   'quedan',
#   'defunción',
#   'múltiples',
#   'prácticas',
#   'labores',
#   'abastos',
#   'informales',
#   'ales',
#   'entregado',
#   'torturaban',
#   'denunciaron',
#   'hogar',
#   'golpeada',
#   'señaladas',
#   'necesitaban',
#   'montaje',
#   'chalo',
#   'necesidades',
#   'comerciantes',
#   'creí',
#   'creía',
#   'herido',
#   'joh',
#   'rurales',
#   'asegurar',
#   'nietos',
#   'casé',
#   'posibles',
#   'ascenso',
#   'alimentaron',
#   'engañándolos',
#   'cicatrices',
#   'secuelas'],
#  'cluster 24': ['gente',
#   'forma',
#   'casos',
#   'información',
#   'agarrado',
#   'fuentes',
#   'llego',
#   'imaginan',
#   'abandono',
#   'pagaban',
#   'ciudadanos',
#   'estuve',
#   'tocó',
#   'gustaba',
#   'recibe',
#   'bar',
#   'ejecutar',
#   'abundancia',
#   'domingos',
#   'dirijo',
#   'fines',
#   'condujo',
#   'riendas',
#   'elider',
#   'aparte',
#   'bajado',
#   'humildes',
#   'matado',
#   'coordinado',
#   'mario',
#   'dinero',
#   'decidieron',
#   'manifestar',
#   'sexto',
#   'operandis',
#   'demandbase',
#   'confirmar',
#   'ballena',
#   'inspecciones',
#   'identificó',
#   'vendía',
#   'convirtió',
#   'tierras',
#   'mata',
#   'afán',
#   'entregaba',
#   'caro',
#   'fútbol',
#   'santo',
#   'cebolla',
#   'uribe',
#   'mula',
#   'pedía',
#   'arenas',
#   'chicos',
#   'café',
#   'frijo',
#   'cultivar']}

# %%
PromptInicio = [
    'A partir del diccionario de clusters de palabras proporcionado, identifica el tema o tópico principal que mejor represente a cada cluster.',
    'Recuerda que las palabras en cada cluster fueron obtenidas mediante un método de agrupamiento basado en una red de bigramas extraídos de descripciones de videos de YouTube sobre el Caso 03 de la JEP.',
    'Las palabras están ordenadas de mayor a menor relevancia dentro de cada cluster, y reflejan conceptos clave en torno a ejecuciones extrajudiciales, víctimas, agentes del Estado y el contexto del conflicto armado en Colombia.'
]

PromptFinal = [
    'Al momento de devolver los datos contesta con el siguiente formato: Numerodecluster:[dato] TemaoTopicoPrincipal:[dato]',
    'Solo contesta con el formato suministrado. Ten en cuenta que los datos provienen de descripciones de videos sobre crímenes de Estado en el marco del Caso 03 de la JEP.'
]


# Constructing the request by joining prompts, dictionary, and final prompts
request = " ".join(PromptInicio) + str(diccionario) + " ".join(PromptFinal)

# %%
request
# Out:
# "A partir del diccionario de clusters de palabras proporcionado, identifica el tema o tópico principal que mejor represente a cada cluster. Recuerda que las palabras en cada cluster fueron obtenidas mediante un método de agrupamiento basado en una red de bigramas extraídos de descripciones de videos de YouTube sobre el Caso 03 de la JEP. Las palabras están ordenadas de mayor a menor relevancia dentro de cada cluster, y reflejan conceptos clave en torno a ejecuciones extrajudiciales, víctimas, agentes del Estado y el contexto del conflicto armado en Colombia.{'cluster 1': ['mí', 'vida', 'acuerdo', 'compromiso', 'positivos', 'derechos', 'marcha', 'impunidad', 'restaurativo', 'versiones', 'estatales', 'empezó', 'pase', 'empecé', 'operacionales', 'escuchó', 'internacional', 'jamás', 'secuestro', 'pechi', 'dejaba', 'cometimos', 'espero', 'perpetrados', 'conoció', 'comunidad', 'colaboraba', 'decisivos', 'conjuró', 'aceptar', 'pelotón', 'hayan', 'informes', 'manos', 'enorme', 'armado', 'afectadas', 'desenterrar', 'favorita', 'partecitas', 'mente', 'carpa', 'permitiera', 'honor', 'quedar', 'legal', 'obligados', 'justificara', 'transformó', 'entender', 'derecho', 'injustamente', 'invito', 'observaciones', 'devia', 'generaba', 'concluir', 'jornalero', 'llamados', 'fatales', 'humanitario', 'riguroso', 'llevaron', 'acusaciones', 'picada', 'reducir', 'padecido', 'tuvieron', 'barbarie', 'transicional', 'levantar', 'contrastación', 'indicadores', 'sacó', 'frutas', 'corte', 'pasando', 'titánica', 'queda', 'planeamiento', 'llegaron', 'doy', 'medi', 'competencia', 'ongs', 'vivíamos', 'ocurrir', 'instituciones', 'jesucristo', 'recibido', 'esfuerzos', 'colocaron', 'ponía', 'robó', 'fuente', 'tapaban', 'avivó', 'venga', 'ruta', 'recuperar', 'investigar', 'anteriores', 'devolverles', 'trazó', 'conformaban', 'rescatar', 'llenó', 'volvió', 'cuide', 'administrativa', 'dolores', 'manejar'], 'cluster 2': ['casa', 'muerto', 'reportaron', 'mentiras', 'dando', 'llevan', 'llevo', 'supuestamente', 'pensaba', 'sueños', 'asesinaron', 'llegaban', 'ah', 'arma', 'noche', 'líder', 'vivo', 'soldado', 'chamo', 'garantía', 'olvidarlo', 'cerquita', 'paró', 'hora', 'triste', 'gritar', 'comparecer', 'cobardemente', 'finca', 'agüita', 'vi', 'pare', 'camine', 'secuestrado', 'subieron', 'llevándolos', 'disparándoles', 'retenido', 'tarra', 'listo', 'patrullas', 'soldados', 'reclutado', 'decimos', 'paramilitarismo', 'íbamos', 'regaló', 'casas', 'pasaba', 'cercas', 'aportes', 'buscando', 'sueño', 'correr', 'caminamos', 'amarrado', 'justificación', 'extender', 'bombril', 'dormir', 'reconociendo', 'colchones', 'metidos', 'estuvieron', 'vereda', 'pita', 'agaron', 'mire', 'alargar', 'cayendo', 'agarraste', 'salieron', 'potreros', 'paré', 'galleta', 'sacudieron', 'afuera', 'sangre', 'cansado', 'asesinos', 'ilusión', 'sabíamos', 'esperándonos', 'engaños', 'pensé', 'reultado', 'acarí', 'bocado', 'tomara', 'bordo', 'use', 'largó', 'podía', 'hamaca', 'peg', 'amarrar', 'oiga', 'cagado', 'cortecito', 'regala', 'puros', 'quedo', 'fría', 'llevaban', 'esposado', 'modos', 'sangrero', 'llenaban', 'cuesten', 'atrás', 'dígame', 'berraquera', 'midiendo'], 'cluster 3': ['persona', 'dios', 'conocimiento', 'seleccionados', 'detrás', 'créame', 'peor', 'conflicto', 'inocentes', 'compartir', 'quitaron', 'inocente', 'cuerpo', 'trabajador', 'mató', 'indefensión', 'trabajadora', 'asesinamos', 'sigo', 'tomé', 'ganaba', 'homicidios', 'mal', 'huye', 'veían', 'enferma', 'causando', 'cambio', 'llevó', 'reportamos', 'arrepientan', 'millón', 'pendiente', 'humano', 'hombre', 'edad', 'atroces', 'asesinar', 'bendiga', 'acuerde', 'amando', 'querida', 'perdona', 'perdonarla', 'normal', 'decisiones', 'salud', 'martín', 'limonal', 'sobreprotector', 'alegría', 'acompáñenos', 'queríamos', 'arrebatarles', 'perdonamos', 'homicida', 'perdono', 'delito', 'debía', 'juzgarle', 'pídanle', 'deseo', 'abajo', 'confía', 'quedé', 'engañamos', 'agarraron', 'humilde', 'llevábamos', 'cantidad', 'desconfiados', 'peñaranda', 'ejecutor' ...

# %%
request = request
chat_completion = openai.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": request,
        }
    ],
    model="gpt-4-1106-preview",
    max_tokens=2000,  # Increase the number of tokens allowed
    temperature=0.7,  # Reduce "creativity" to obtain precise responses
    top_p=1,  # Adjust maximum probability to ensure precise responses
)
respuesta = chat_completion.choices[0].message.content

# %%
print(respuesta)
# Out:
# Numerodecluster:1 TemaoTopicoPrincipal:Proceso de justicia y reparación en el contexto de la JEP
# Numerodecluster:2 TemaoTopicoPrincipal:Relatos de víctimas y reconstrucción de eventos violentos
# Numerodecluster:3 TemaoTopicoPrincipal:Impacto humano y emocional del conflicto armado
# Numerodecluster:4 TemaoTopicoPrincipal:Desarrollo del proceso judicial y búsqueda de verdad
# Numerodecluster:5 TemaoTopicoPrincipal:Responsabilidad social y ética en el contexto del conflicto
# Numerodecluster:6 TemaoTopicoPrincipal:Procesos y estructuras militares relacionados con el conflicto
# Numerodecluster:7 TemaoTopicoPrincipal:Identificación y recuperación de cuerpos de víctimas
# Numerodecluster:8 TemaoTopicoPrincipal:Testimonios y experiencias personales relacionadas con el conflicto
# Numerodecluster:9 TemaoTopicoPrincipal:Marco legal y políticas de reparación y reincorporación
# Numerodecluster:10 TemaoTopicoPrincipal:Impacto del conflicto en las familias y llamados a la empatía y reconciliación
# Numerodecluster:11 TemaoTopicoPrincipal:Mecanismos de justicia transicional y reconocimiento de responsabilidades
# Numerodecluster:12 TemaoTopicoPrincipal:Retos en la reconstrucción de la memoria y dignidad
# Numerodecluster:13 TemaoTopicoPrincipal:Rol del ejército y estructuras de comando implicadas en el conflicto
# Numerodecluster:14 TemaoTopicoPrincipal:Metodologías y patrones de violencia asociados al conflicto
# Numerodecluster:15 TemaoTopicoPrincipal:Interacciones personales y nombres asociados al conflicto
# Numerodecluster:16 TemaoTopicoPrincipal:Impacto social y político del conflicto en Colombia
# Numerodecluster:17 TemaoTopicoPrincipal:Experiencias individuales y responsabilidad en actos de violencia
# Numerodecluster:18 TemaoTopicoPrincipal:Denuncias y responsabilidad en la perpetuación de crímenes
# Numerodecluster:19 TemaoTopicoPrincipal:Responsabilidad de altos mandos y estructura de comando
# Numerodecluster:20 TemaoTopicoPrincipal:Desafíos en la búsqueda de la verdad y la justicia
# Numerodecluster:21 TemaoTopicoPrincipal:Detalles de los actos de violencia y sus consecuencias
# Numerodecluster:22 TemaoTopicoPrincipal:Condiciones y circunstancias de la vida en zonas de conflicto
# Numerodecluster:23 TemaoTopicoPrincipal:Impacto del conflicto en comunidades y regiones específicas
# Numerodecluster:24 TemaoTopicoPrincipal:Aspectos sociales y económicos relacionados con el conflicto

# %%
with open("clusters_theme.txt", "w", encoding="utf-8") as file:
    file.write(respuesta)
