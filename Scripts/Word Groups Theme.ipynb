# %% [markdown]
# # THEMES FOR WORD GROUPS USING OpenAI
#
# **Authors**
# - Alejandro Urrego Lopéz
# - Cesar Augusto Prieto Sarmiento
#
# This python notebook contains the development of the code with which using the AI to generate the main themes or topics for each word group generated by the best clustering algorithm.

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd   # For data manipulations
import numpy as np    # For maths
import igraph as ig   # For networks 
import openai        # AI implementations
from dotenv import load_dotenv

import os
load_dotenv()

# %%
data_folder_path = os.path.dirname(os.getcwd()) + os.sep + 'Outputs' + os.sep

# %%
# Definir la ruta del directorio de trabajo
directorio_trabajo = r'C:/Users/Pc/Desktop/-Proyecto-JEP-/Outputs/Skipgrams - victims/Antioquia'
# Norte de santander
# Costa Caribe
# Casanare
# Meta
# Huila
# Antioquia
# Cambiar el directorio de trabajo
os.chdir(directorio_trabajo)

# %%
directorio_trabajo
# Out:
# 'C:/Users/Pc/Desktop/-Proyecto-JEP-/Outputs/Skipgrams - victims/Antioquia'

# %% [markdown]
# ## Development and research of topics

# %%
clusters = pd.read_csv('clusters_jep.txt')
clusters=clusters.sort_values(by='eigen', ascending=False)
clusters
# Out:
#          word  cluster     eigen
# 482  víctimas       19  1.000000
# 5     ustedes       19  0.821711
# 37   personas        2  0.609388
# 71        día        1  0.401704
# 1    justicia       19  0.397685
# ..        ...      ...       ...
# 321   comidas        7  0.000004
# 195     denis        1  0.000004
# 630     estás       18  0.000003
# 432       mío        7  0.000003
# 383   galleta        7  0.000003
#
# [709 rows x 3 columns]

# %%
diccionario = {}
for i in set(clusters['cluster']):
    diccionario['cluster '+str(i)] = clusters.query('cluster==@i')['word'].tolist()

# %%
diccionario
# Out:
# {'cluster 1': ['día',
#   'vida',
#   'mí',
#   'ejército',
#   'familia',
#   'hijo',
#   'mis',
#   'casa',
#   'sé',
#   'padre',
#   'hermano',
#   'hijos',
#   'persona',
#   'mamá',
#   'papá',
#   'comunidad',
#   'padres',
#   'madre',
#   'madres',
#   'guerrillero',
#   'hermanos',
#   'niño',
#   'duele',
#   'antonio',
#   'encontrar',
#   'damos',
#   'casas',
#   'agradezco',
#   'encontraron',
#   'esposa',
#   'desaparecido',
#   'seguiremos',
#   'hermana',
#   'hombre',
#   'esposo',
#   'asesinados',
#   'pagar',
#   'duro',
#   'mató',
#   'gente',
#   'armas',
#   'pensé',
#   'tío',
#   'resulta',
#   'fuerza',
#   'presencia',
#   'esposos',
#   'comida',
#   'leonardo',
#   'venteros',
#   'velázquez',
#   'normal',
#   'engañado',
#   'suplicaba',
#   'robaron',
#   'caminaba',
#   'baja',
#   'noche',
#   'dispararle',
#   'aporrear',
#   'desaparición',
#   'amigos',
#   'delante',
#   'hijito',
#   'alegre',
#   'asesino',
#   'quedé',
#   'dígame',
#   'ayudarle',
#   'quedaron',
#   'abuelo',
#   'reclamando',
#   'viuda',
#   'hijas',
#   'pueblo',
#   'niña',
#   'castillo',
#   'manuel',
#   'trabajadora',
#   'carmona',
#   'carretas',
#   'carretica',
#   'supuestamente',
#   'serio',
#   'consiguiéndose',
#   'caballo',
#   'darbey',
#   'quintero',
#   'comidita',
#   'denis'],
#  'cluster 2': ['personas',
#   'caso',
#   'familias',
#   'asesinatos',
#   'seres',
#   'asesinadas',
#   'quiénes',
#   'niños',
#   'desapariciones',
#   'pasó',
#   'combate',
#   'extrajudiciales',
#   'bajas',
#   'visto',
#   'siguen',
#   'presentadas',
#   'mujeres',
#   'tenían',
#   'edad',
#   'patrón',
#   'tarde',
#   'desaparecidas',
#   'asesinato',
#   'vulnerables',
#   'muerte',
#   'territorio',
#   'cientos',
#   'traer',
#   'marzo',
#   'tuvieron',
#   'forzada',
#   'dónde',
#   'sueños',
#   'priorizado',
#   'búsqueda',
#   'forzadas',
#   'presentados',
#   'agentes',
#   'comunidades',
#   'cuerpo',
#   'queridos',
#   'ilegítimamente',
#   'vidas',
#   'familiar',
#   'desaparecidos',
#   'criminal',
#   'cometidas',
#   'falsamente',
#   'falsas',
#   'guerrilleros',
#   'presentaron',
#   'criminalmente',
#   'presentado',
#   'capítulo',
#   'supuestas',
#   'falsa',
#   'presentarlas',
#   'junio',
#   'muertes',
#   'repite',
#   'ocultamiento',
#   'retomar',
#   'esteli',
#   'ensañaron',
#   'dadas',
#   'indefensión',
#   'presentar',
#   'campesinos',
#   'laborales',
#   'protocolo',
#   'significa',
#   'vulnerable'],
#  'cluster 3': ['maría',
#   'luz',
#   'presente',
#   'luis',
#   'gómez',
#   'alberto',
#   'giraldo',
#   'santa',
#   'jesús',
#   'gonzález',
#   'ríos',
#   'bermúdez',
#   'castro',
#   'gallego',
#   'areiza',
#   'wilson',
#   'castañeda',
#   'fernando',
#   'esperanza',
#   'ramírez',
#   'morales',
#   'martínez',
#   'fredy',
#   'pico',
#   'john',
#   'carlos',
#   'hernández',
#   'darío',
#   'johan',
#   'lópez',
#   'lotero',
#   'pres',
#   'acabaron',
#   'cerna',
#   'naranjo',
#   'muñoz',
#   'garcía',
#   'restrepo',
#   'arias',
#   'mejía',
#   'carmen',
#   'leandro',
#   'juliana',
#   'galeano',
#   'vélez',
#   'idarraga',
#   'suárez',
#   'pino',
#   'montes',
#   'bedoya',
#   'miguel',
#   'mauricio',
#   'gonzalo',
#   'león',
#   'diego',
#   'jaime',
#   'janet',
#   'cristian',
#   'cañas',
#   'álvarez',
#   'navarro',
#   'agudelo',
#   'jurado',
#   'álvaro',
#   'roberto',
#   'arboleda',
#   'javier',
#   'germán',
#   'césar',
#   'correa',
#   'josué',
#   'sáchica',
#   'villegas',
#   'pinzona',
#   'trujillo',
#   'cortés',
#   'vidal'],
#  'cluster 4': ['derecho',
#   'derechos',
#   'organizaciones',
#   'jóvenes',
#   'representación',
#   'escenario',
#   'centro',
#   'corte',
#   'humanitario',
#   'graves',
#   'región',
#   'jurídico',
#   'precisamente',
#   'internacional',
#   'recuerdos',
#   'directora',
#   'humanos',
#   'ejecutiva',
#   'negrito',
#   'violaciones',
#   'defensoras',
#   'interamericana'],
#  'cluster 5': ['restauración', 'social', 'restablecer'],
#  'cluster 6': ['sistema', 'transicional', 'sistemas'],
#  'cluster 7': ['punto',
#   'militar',
#   'cementerio',
#   'compañero',
#   'hacía',
#   'cuerpos',
#   'prestar',
#   'instrucción',
#   'sabía',
#   'davea',
#   'negro',
#   'fosas',
#   've',
#   'valoramos',
#   'conmigo',
#   'te',
#   'trabajemos',
#   'informales',
#   'comidas',
#   'mío',
#   'galleta'],
#  'cluster 8': ['versiones',
#   'colectivas',
#   'público',
#   'observaciones',
#   'marco',
#   'voluntarias',
#   'investiga',
#   'medalla',
#   'distinguidos',
#   'armado',
#   'diligencias',
#   'tortura'],
#  'cluster 9': ['mano', 'hora', 'zurdo', 'receso'],
#  'cluster 10': ['detallada', 'completa', 'exhaustiva'],
#  'cluster 11': ['hubiera', 'roja'],
#  'cluster 12': ['conflicto', 'positivos', 'interno', 'violencia', 'llamados'],
#  'cluster 13': ['procurador',
#   'catalina',
#   'óscar',
#   'palabras',
#   'jairo',
#   'díaz',
#   'parra',
#   'acosta',
#   'durango',
#   'funciones',
#   'vera',
#   'colega',
#   'dr',
#   'julián',
#   'emilio',
#   'delegado',
#   'garín'],
#  'cluster 14': ['nacional',
#   'brigada',
#   'militares',
#   'batallón',
#   'crímenes',
#   'general',
#   'daño',
#   'miembros',
#   'corral',
#   'tropas',
#   'unidad',
#   'cuarta',
#   'vial',
#   'número',
#   'comandante',
#   'medicina',
#   'batallones',
#   'eduardo',
#   'artillería',
#   'nelos',
#   'adscrita',
#   'legal',
#   'granaderos',
#   'amor',
#   'jorge',
#   'comando',
#   'comandantes',
#   'carepa',
#   'coronel',
#   'energético',
#   'caballería',
#   'justo',
#   'infantería',
#   'pedro',
#   'civiles',
#   'espina',
#   'ospina',
#   'concentra',
#   'girardo',
#   'peña',
#   'máximos',
#   'ejecución',
#   'perpetradores',
#   'reparar',
#   'penal',
#   'ingenieros',
#   'acusación',
#   'atanasio',
#   'atanacio',
#   'época',
#   'instituto',
#   'bajes',
#   'rodríguez',
#   'badillo',
#   'cu',
#   'bosp',
#   'sánchez',
#   'nación',
#   'ortiz',
#   'caribe',
#   'parrado',
#   'girardot',
#   'salazar',
#   'berrío',
#   'trabajadoras',
#   'juez',
#   'nelson',
#   'baj'],
#  'cluster 15': ['guerrilla',
#   'fuerzas',
#   'mañana',
#   'integrantes',
#   'grupo',
#   'ley',
#   'paramilitares',
#   'urbanas',
#   'antiterroristas',
#   'antiguos',
#   'final',
#   'instalar',
#   'hicimos',
#   'armados',
#   'mecanizada',
#   'mecanizado',
#   'llega',
#   'exigimos',
#   'especiales',
#   'feur',
#   'juan',
#   'agrupación',
#   'trabajando',
#   'forero',
#   'villa',
#   'barrera',
#   'viveros'],
#  'cluster 16': ['soldados',
#   'mataron',
#   'bajaban',
#   'manos',
#   'llevaron',
#   'hablar',
#   'disparos',
#   'arma',
#   'embarazo',
#   'derecha'],
#  'cluster 17': ['audiencia',
#   'importante',
#   'escuchar',
#   'doña',
#   'testimonio',
#   'pública',
#   'querido',
#   'presentación',
#   'sumamente',
#   'continuación',
#   'continuar',
#   'video',
#   'compartir',
#   'querer',
#   'aplausos',
#   'don',
#   'ambulante',
#   'tu',
#   'razón',
#   'ah',
#   'retomamos',
#   'cerrar',
#   'viboral',
#   'valioso',
#   'graciela',
#   'paso',
#   'pina',
#   'elena',
#   'pureza',
#   'trinidad',
#   'marina',
#   'sofía',
#   'ofelia',
#   'lilia',
#   'isabel',
#   'rosa',
#   'breve',
#   'danilo',
#   'presencial',
#   'abelardo',
#   'pasar',
#   'paula',
#   'contar',
#   'viendo',
#   'ernesto',
#   'bola',
#   'permite',
#   'tus',
#   'vallejo'],
#  'cluster 18': ['universidad', 'estudio', 'calle', 'colegio', 'estás'],
#  'cluster 19': ['víctimas',
#   'ustedes',
#   'justicia',
#   'quiero',
#   'días',
#   'comparecientes',
#   'país',
#   'jep',
#   'especial',
#   'proceso',
#   'familiares',
#   'paz',
#   'historia',
#   'saludo',
#   'magistrados',
#   'reconocimiento',
#   'señores',
#   'responsables',
#   'tardes',
#   'seguir',
#   'reparación',
#   'valentía',
#   'reconocer',
#   'colombia',
#   'escuchado',
#   'testimonios',
#   'daños',
#   'buscando',
#   'responsabilidad',
#   'lucha',
#   'cordial',
#   'presentes',
#   'espacio',
#   'darle',
#   'voz',
#   'sociedad',
#   'frente',
#   'fundamental',
#   'nuevamente',
#   'perdón',
#   'participación',
#   'dios',
#   'forma',
#   'magistratura',
#   'departamento',
#   'procesos',
#   'oportunidad',
#   'representantes',
#   'información',
#   'diligencia',
#   'esperamos',
#   'respetuoso',
#   'fase',
#   'permitirá',
#   'acto',
#   'pedirle',
#   'podido',
#   'recinto',
#   'relatos',
#   'mundo',
#   'relación',
#   'ojalá',
#   'acompañan',
#   'audiencias',
#   'abrazo',
#   'victimarios',
#   'decirles',
#   'abogados',
#   'registro',
#   'hombres',
#   'eje',
#   'efectiva',
#   'judicial',
#   'identificar',
#   'vengo',
#   'magistradas',
#   'finalmente',
#   'corresponde',
#   'futuro',
#   'memoria',
#   'coraje',
#   'esté',
#   'sentido',
#   'em',
#   'digo',
#   'buscar',
#   'cara',
#   'temor',
#   'dando',
#   'g',
#   'conocen',
#   'lágrimas',
#   'dejar',
#   'entereza',
#   'central',
#   'públicamente',
#   'difícil',
#   'corazón',
#   'pie',
#   'momentos',
#   'intervención',
#   'repetición',
#   'garantizar',
#   'defensa',
#   'luchas',
#   'impunidad',
#   'garantías',
#   'camino',
#   'iba',
#   'críticas',
#   'restaurativos',
#   'sanación',
#   'versión',
#   'digan',
#   'mensaje',
#   'mencionar',
#   'especialmente',
#   'claro',
#   'adecuado',
#   'gobierno',
#   'compromiso',
#   'disposición',
#   'magnitud',
#   'carolina',
#   'participantes',
#   'acuerdo',
#   'duradera',
#   'determinación',
#   'considerados',
#   'seleccionados',
#   'contribuir',
#   'conductas',
#   'sepultura',
#   'absolutamente',
#   'conozca',
#   'indeterminadas',
#   'entera',
#   'definición',
#   'equipos',
#   'jurídicas'],
#  'cluster 20': ['medellín',
#   'antioquia',
#   'casos',
#   'oriente',
#   'ocurrió',
#   'ejecuciones',
#   'antioqueño',
#   'nordeste',
#   'norte',
#   'población',
#   'haga',
#   'mercedes',
#   'falsos',
#   'investigación',
#   'municipios',
#   'engaño',
#   'zona',
#   'aburrá',
#   'conjunto',
#   'abril',
#   'periodo',
#   'promedio',
#   'ocurrieron',
#   'atención',
#   'priorizados',
#   'macrocasos',
#   'luchando',
#   'aquella',
#   'bolívar',
#   'medio',
#   'magdalena',
#   'sur',
#   'esclarezca',
#   'política',
#   'persistir',
#   'división',
#   'democrática'],
#  'cluster 21': ['dolor',
#   'solidaridad',
#   'supuesto',
#   'volver',
#   'ordinaria',
#   'equipo',
#   'inmenso',
#   'profundo',
#   'habla',
#   'pérdida',
#   'políticos',
#   'restaurativa'],
#  'cluster 22': ['municipio',
#   'granada',
#   'muestra',
#   'vereda',
#   'guerra',
#   'asesinado',
#   'marta',
#   'santana',
#   'corregimiento',
#   'beiba',
#   'humanidad',
#   'allí',
#   'bárbara',
#   'puerto',
#   'dijimos',
#   'ciudad',
#   'finca',
#   'alto',
#   'grande',
#   'lesa',
#   'nicolás',
#   'ana',
#   'corporación',
#   'crimen',
#   'marino',
#   'valle',
#   'vallesteros',
#   'libertad',
#   'asociación',
#   'cimitarra']}

# %%
PromptInicio = [
    'A partir del diccionario de clusters de palabras proporcionado, identifica el tema o tópico principal que mejor represente a cada cluster.',
    'Recuerda que las palabras en cada cluster fueron obtenidas mediante un método de agrupamiento basado en una red de bigramas extraídos de descripciones de videos de YouTube sobre el Caso 03 de la JEP.',
    'Las palabras están ordenadas de mayor a menor relevancia dentro de cada cluster, y reflejan conceptos clave en torno a ejecuciones extrajudiciales, víctimas, agentes del Estado y el contexto del conflicto armado en Colombia.'
]

PromptFinal = [
    'Al momento de devolver los datos contesta con el siguiente formato: Numerodecluster:[dato] TemaoTopicoPrincipal:[dato]',
    'Solo contesta con el formato suministrado. Ten en cuenta que los datos provienen de descripciones de videos sobre crímenes de Estado en el marco del Caso 03 de la JEP.'
]


# Constructing the request by joining prompts, dictionary, and final prompts
request = " ".join(PromptInicio) + str(diccionario) + " ".join(PromptFinal)

# %%
request
# Out:
# "A partir del diccionario de clusters de palabras proporcionado, identifica el tema o tópico principal que mejor represente a cada cluster. Recuerda que las palabras en cada cluster fueron obtenidas mediante un método de agrupamiento basado en una red de bigramas extraídos de descripciones de videos de YouTube sobre el Caso 03 de la JEP. Las palabras están ordenadas de mayor a menor relevancia dentro de cada cluster, y reflejan conceptos clave en torno a ejecuciones extrajudiciales, víctimas, agentes del Estado y el contexto del conflicto armado en Colombia.{'cluster 1': ['día', 'vida', 'mí', 'ejército', 'familia', 'hijo', 'mis', 'casa', 'sé', 'padre', 'hermano', 'hijos', 'persona', 'mamá', 'papá', 'comunidad', 'padres', 'madre', 'madres', 'guerrillero', 'hermanos', 'niño', 'duele', 'antonio', 'encontrar', 'damos', 'casas', 'agradezco', 'encontraron', 'esposa', 'desaparecido', 'seguiremos', 'hermana', 'hombre', 'esposo', 'asesinados', 'pagar', 'duro', 'mató', 'gente', 'armas', 'pensé', 'tío', 'resulta', 'fuerza', 'presencia', 'esposos', 'comida', 'leonardo', 'venteros', 'velázquez', 'normal', 'engañado', 'suplicaba', 'robaron', 'caminaba', 'baja', 'noche', 'dispararle', 'aporrear', 'desaparición', 'amigos', 'delante', 'hijito', 'alegre', 'asesino', 'quedé', 'dígame', 'ayudarle', 'quedaron', 'abuelo', 'reclamando', 'viuda', 'hijas', 'pueblo', 'niña', 'castillo', 'manuel', 'trabajadora', 'carmona', 'carretas', 'carretica', 'supuestamente', 'serio', 'consiguiéndose', 'caballo', 'darbey', 'quintero', 'comidita', 'denis'], 'cluster 2': ['personas', 'caso', 'familias', 'asesinatos', 'seres', 'asesinadas', 'quiénes', 'niños', 'desapariciones', 'pasó', 'combate', 'extrajudiciales', 'bajas', 'visto', 'siguen', 'presentadas', 'mujeres', 'tenían', 'edad', 'patrón', 'tarde', 'desaparecidas', 'asesinato', 'vulnerables', 'muerte', 'territorio', 'cientos', 'traer', 'marzo', 'tuvieron', 'forzada', 'dónde', 'sueños', 'priorizado', 'búsqueda', 'forzadas', 'presentados', 'agentes', 'comunidades', 'cuerpo', 'queridos', 'ilegítimamente', 'vidas', 'familiar', 'desaparecidos', 'criminal', 'cometidas', 'falsamente', 'falsas', 'guerrilleros', 'presentaron', 'criminalmente', 'presentado', 'capítulo', 'supuestas', 'falsa', 'presentarlas', 'junio', 'muertes', 'repite', 'ocultamiento', 'retomar', 'esteli', 'ensañaron', 'dadas', 'indefensión', 'presentar', 'campesinos', 'laborales', 'protocolo', 'significa', 'vulnerable'], 'cluster 3': ['maría', 'luz', 'presente', 'luis', 'gómez', 'alberto', 'giraldo', 'santa', 'jesús', 'gonzález', 'ríos', 'bermúdez', 'castro', 'gallego', 'areiza', 'wilson', 'castañeda', 'fernando', 'esperanza', 'ramírez', 'morales', 'martínez', 'fredy', 'pico', 'john', 'carlos', 'hernández', 'darío', 'johan', 'lópez', 'lotero', 'pres', 'acabaron', 'cerna', 'naranjo', 'muñoz', 'garcía', 'restrepo', 'arias', 'mejía', 'carmen', 'leandro', 'juliana', 'galeano', 'vélez', 'idarraga', 'suárez', 'pino', 'montes', 'bedoya', 'miguel', 'mauricio', 'gonzalo', 'león', 'diego', 'jaime', 'janet', 'cristian', 'cañas', 'álvarez', 'navarro', 'agudelo', 'jurado', 'álvaro', 'roberto', 'arboleda', 'javier', 'germán', 'césar', 'correa', 'josué', 'sáchica', 'villegas', 'pinzona', 'trujillo', 'cortés', 'vidal'], 'cluster 4': ['derecho', 'derechos', 'organizaciones', 'jóvenes', 'representación', 'escenario', 'centro', 'corte', 'humanitario', 'graves', 'región', 'jurídico', 'precisamente', 'internacional', 'recuerdos', 'directora', 'humanos', 'ejecutiva', 'negrito', 'violaciones', 'defensoras', 'interamericana'], 'cluster 5': ['restauración', 'social', 'restablecer'], 'cluster 6': ['sistema', 'transicional', 'sistemas'], 'cluster 7': ['punto', 'militar', 'cementerio', 'compañero', 'hacía', 'cuerpos', 'prestar', 'instrucción', 'sabía', 'davea', 'negro', 'fosas', 've', 'valoramos', 'conmigo', 'te', 'trabajemos', 'informales', 'comidas', 'mío', 'galleta'], 'cluster 8': ['versiones', 'colectivas', 'público', 'observaciones', 'marco', 'voluntarias', 'investiga', 'medal ...

# %%
request = request
chat_completion = openai.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": request,
        }
    ],
    model="gpt-4-1106-preview",
    max_tokens=2000,  # Increase the number of tokens allowed
    temperature=0.7,  # Reduce "creativity" to obtain precise responses
    top_p=1,  # Adjust maximum probability to ensure precise responses
)
respuesta = chat_completion.choices[0].message.content

# %%
print(respuesta)
# Out:
# Numerodecluster:1 TemaoTopicoPrincipal:Impacto en la vida cotidiana y familiar de las víctimas
# Numerodecluster:2 TemaoTopicoPrincipal:Víctimas y patrones de asesinatos y desapariciones
# Numerodecluster:3 TemaoTopicoPrincipal:Nombres propios y posibles víctimas o involucrados
# Numerodecluster:4 TemaoTopicoPrincipal:Derechos humanos y organismos de defensa
# Numerodecluster:5 TemaoTopicoPrincipal:Reparación y restablecimiento social
# Numerodecluster:6 TemaoTopicoPrincipal:Sistema de justicia transicional
# Numerodecluster:7 TemaoTopicoPrincipal:Contexto militar y hallazgo de cuerpos
# Numerodecluster:8 TemaoTopicoPrincipal:Procedimientos y mecanismos de justicia
# Numerodecluster:9 TemaoTopicoPrincipal:Detalles específicos o técnicos (posiblemente relacionados con las audiencias)
# Numerodecluster:10 TemaoTopicoPrincipal:Profundidad en la investigación o análisis
# Numerodecluster:11 TemaoTopicoPrincipal:Elementos simbólicos o descriptivos (posiblemente relacionados con la violencia)
# Numerodecluster:12 TemaoTopicoPrincipal:Conflicto armado interno y violencia
# Numerodecluster:13 TemaoTopicoPrincipal:Actores jurídicos y representantes legales
# Numerodecluster:14 TemaoTopicoPrincipal:Estructura y crímenes militares
# Numerodecluster:15 TemaoTopicoPrincipal:Grupos armados y operativos militares
# Numerodecluster:16 TemaoTopicoPrincipal:Relatos de acciones violentas y víctimas
# Numerodecluster:17 TemaoTopicoPrincipal:Procedimiento y desarrollo de las audiencias
# Numerodecluster:18 TemaoTopicoPrincipal:Educación y entornos urbanos
# Numerodecluster:19 TemaoTopicoPrincipal:Justicia, víctimas y proceso de la JEP
# Numerodecluster:20 TemaoTopicoPrincipal:Casos específicos y regionalización del conflicto
# Numerodecluster:21 TemaoTopicoPrincipal:Sentimientos y justicia restaurativa
# Numerodecluster:22 TemaoTopicoPrincipal:Localidades y crímenes específicos

# %%
with open("clusters_theme.txt", "w", encoding="utf-8") as file:
    file.write(respuesta)
